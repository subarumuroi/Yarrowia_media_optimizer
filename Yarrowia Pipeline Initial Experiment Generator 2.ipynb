# %% [markdown]
# # Yarrowia Media Matrix VERSION 2 (usses the latest changes 3/Sept/2025)
# This is a redo of initial generator 1 to finalise the clusters with the changes made to Justin's programmatic pipette
# ### this usses the output from mediamatrixgen
# Therefore changes were made accordingly based on changes to his new code.
# ### Takes generated media matrix and clusters groups for dimensionality reduction. Arbitrarily sets bounds and cluster groups, then uses LHS to sample points within bounds for initial experimental set.
#
# #### this file is mostly copied from 'Yarrowia linear hierarchial tree reduction.ipynb' from ML_for_rational_design repo

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import itertools

from scipy.spatial.distance import squareform
from scipy.cluster.hierarchy import linkage, dendrogram

from pyDOE3 import lhs
import torch

# %%
# read in g/L data for dimensional reduction 
df = pd.read_csv(".\Generator 2 io data\Media-Matrix-Combined-grams-per-litre-Annotate.csv")

#df = pd.read_csv("data/Media-Matrix-Combined-v5-moles-per-litre.csv")  # uncomment this line to use mol/L version

# mol/L version will give same cluster results

# filter rows that are considered not important
compounds_to_remove = [
    'Dipotassium phosphate', 'Disodium edta dihydrate', 'EDTA', 'Monopotassium phosphate',
    'Potassium hydroxide', 'Sodium citrate dihydrate', 'Sodium phosphate',
    'Uracil', 
    # also remove redundant elements 
    'Calcium sulphate dihydrate', 'Iron (III) chloride tetrahydrate', 'Manganese (II) sulphate monohydrate',
    'Nickel sulphate heptahydrate', 'Sodium chloride', 'Zinc chloride'

]

df = df[~df['Compound'].isin(compounds_to_remove)].copy()

# remove pubchemid
df.drop(df.columns[1], axis=1, inplace=True)

# separate numeric columns for transformation
num_df = df.select_dtypes(include='number')
labels = df[['Compound', 'Annotate']]

yar_df = df.filter(like='_YAR')
#cer_df = df_log.filter(like='_CER')
#pic_df = df_log.filter(like='_PIC')

yar_df_labeled = pd.concat([labels, yar_df], axis=1)

# Define which columns are sample measurements (everything except metadata)
sample_cols = yar_df_labeled.columns.difference(['Compound', 'Annotate'])

# Filter to keep rows where at least one sample value ≠ 0   # this bit was changed for the linear version of this process pipeline
yar_df_labeled = yar_df_labeled[
    yar_df_labeled['Annotate'].isin(['Vitamin', 'Element']) &
    ~(yar_df_labeled[sample_cols] == 0).all(axis=1)
].copy()

# let's remove redundant elements for calcium iron, manganese, sodium chloride and zinc chloride
# This now redundant as I filter all up top
# yar_df_labeled = yar_df_labeled.drop(index=[9, 16, 29, 35, 46, 59])

yar_df_element = yar_df_labeled[yar_df_labeled['Annotate'] == 'Element'].copy()
yar_df_vitamin = yar_df_labeled[yar_df_labeled['Annotate'] == 'Vitamin'].copy()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\uqkmuroi\AppData\Local\Temp\ipykernel_35040\4010194329.py:2: SyntaxWarning: invalid escape sequence '\G'
#   df = pd.read_csv(".\Generator 2 io data\Media-Matrix-Combined-grams-per-litre-Annotate.csv")

# %% [markdown]
# Eleements hierarchical tree:

# %%
# -------------------------------
# Step 0: Prepare data
# -------------------------------
df_e = yar_df_element.copy()

df_e = df_e.sample(frac=1)  # shuffle rows for randomness
sample_cols = df_e.columns.difference(['Compound', 'Annotate'])

# Adaptive eps adds a small value based on the minimum non-zero value in the dataset
min_nonzero = df_e[sample_cols].replace(0, np.nan).min().min()
eps = min_nonzero*1e-3
# This keeps clustering constant across runs
print(f"Using adpative eps = {eps:.2e}")

# -------------------------------
# Step 1: Compute log-ratio distances
# -------------------------------
ratios = []

# All unique compound pairs
compound_pairs = list(itertools.combinations(df_e['Compound'], 2))

# Map for quick lookup
compound_map = df_e.set_index('Compound')[sample_cols]

for c1, c2 in compound_pairs:
    vals1 = compound_map.loc[c1]
    vals2 = compound_map.loc[c2]

    # log-ratio with pseudocount
    ratio = np.log10(vals1 + eps) - np.log10(vals2 + eps)
    
    # absolute value (fold difference)
    ratio = ratio.abs()
    
    # if all NaN or zero, replace with small value to avoid exact zero distance
    if ratio.notna().sum() == 0:
        ratio[:] = eps

    row = {'Compound_1': c1, 'Compound_2': c2, **ratio.to_dict()}
    ratios.append(row)

ratio_df_e = pd.DataFrame(ratios)

# Drop irrelevant columns
ratio_df_e_reduced = ratio_df_e.drop(columns=['1_YAR','2b_YAR','2c_YAR','2d_YAR','3b_YAR','3c_YAR','6_YAR'], errors='ignore')

# -------------------------------
# Step 2: Compute SD per pair
# -------------------------------
sample_cols = ratio_df_e_reduced.columns.difference(['Compound_1', 'Compound_2'])
ratio_df_e_reduced['Std_Ratio'] = ratio_df_e_reduced[sample_cols].replace(0, np.nan).std(axis=1, skipna=True).fillna(0)

# -------------------------------
# Step 3: Build distance matrix
# -------------------------------
compounds = pd.unique(ratio_df_e_reduced[['Compound_1', 'Compound_2']].values.ravel())
distance_matrix = pd.DataFrame(0, index=compounds, columns=compounds, dtype=float)

for _, row in ratio_df_e_reduced.iterrows():
    c1, c2, std = row['Compound_1'], row['Compound_2'], row['Std_Ratio']
    distance_matrix.loc[c1, c2] = std
    distance_matrix.loc[c2, c1] = std

np.fill_diagonal(distance_matrix.values, 0)

# -------------------------------
# Step 4: Hierarchical clustering
# -------------------------------
# Convert to condensed distance matrix
condensed_dist = squareform(distance_matrix.values)

# Use average linkage
Z = linkage(condensed_dist, method='average')

# -------------------------------
# Step 5: Plot dendrogram
# -------------------------------
plt.figure(figsize=(12, 6))
dendrogram(Z, labels=distance_matrix.index.tolist(), leaf_rotation=90)
plt.yscale('symlog', linthresh=.0001)
plt.ylabel("Linkage Distance (symlog)")
plt.title("Hierarchical Clustering of Compounds (Log-Ratio Std)")
plt.tight_layout()
plt.show()

'''Same thing as std above but for max-min range ratios'''
# -------------------------------
# Step 1: Compute max-min distances per pair
# -------------------------------
range_values = []

for _, row in ratio_df_e_reduced.iterrows():
    vals = row[sample_cols].replace(0, np.nan)  # ignore zeros
    if vals.notna().sum() == 0:
        rng = eps  # avoid NaNs and treats as small distance
    else:
        rng = vals.max() - vals.min()
        if rng == 0:
            rng = eps # gives tiny separation if all values are the same
    range_values.append(rng)

ratio_df_e_reduced['Range'] = range_values

# -------------------------------
# Step 2: Build distance matrix
# -------------------------------
distance_matrix_range = pd.DataFrame(0, index=compounds, columns=compounds, dtype=float)

for _, row in ratio_df_e_reduced.iterrows():
    c1, c2, rng = row['Compound_1'], row['Compound_2'], row['Range']
    distance_matrix_range.loc[c1, c2] = rng
    distance_matrix_range.loc[c2, c1] = rng

np.fill_diagonal(distance_matrix_range.values, 0)

# -------------------------------
# Step 3: Hierarchical clustering
# -------------------------------
condensed_dist_range = squareform(distance_matrix_range.values)
Z_range = linkage(condensed_dist_range, method='average')

# -------------------------------
# Step 4: Plot dendrogram
# -------------------------------
plt.figure(figsize=(12, 6))
dendrogram(Z_range, labels=distance_matrix_range.index.tolist(), leaf_rotation=90)
plt.yscale('symlog', linthresh=0.01)
plt.ylabel("Linkage Distance (max-min range)")
plt.title("Hierarchical Clustering of Compounds (Max-Min Range)")
plt.tight_layout()
plt.show()

'''this bit generates the merge table for the hierarchical clustering'''
# Get compound names
compounds = list(distance_matrix.index)

# Number of original observations
n = len(compounds)

# This will store merge history
merge_history = []

# Track cluster membership (compound names or merged groups)
clusters = {i: [compounds[i]] for i in range(n)}

# Loop over linkage matrix Z
for step, (idx1, idx2, dist, sample_count) in enumerate(Z):
    idx1, idx2 = int(idx1), int(idx2)
    
    # Get the clusters being merged
    members1 = clusters[idx1]
    members2 = clusters[idx2]

    # Merge the two clusters
    new_cluster = members1 + members2
    clusters[n + step] = new_cluster

    # Save merge info
    merge_history.append({
        'Step': step + 1,
        'Cluster_ID': n + step,
        'Merged_Cluster_1': members1,
        'Merged_Cluster_2': members2,
        'Linkage_Distance': dist,
        'Num_Compounds': len(new_cluster),
    })

# Convert to dataframe for easier viewing
merge_df = pd.DataFrame(merge_history)

# Display the merge table sorted by step (or by distance, if you prefer)
merge_df_sorted = merge_df.sort_values('Linkage_Distance', ascending=True)

# Print the table or write to CSV
print(merge_df_sorted.to_string(index=False))

merge_df_sorted[['Step', 'Linkage_Distance']].plot(x='Step', y='Linkage_Distance', marker='o')
plt.ylabel("Linkage Distance (range)")
plt.title("Elbow Plot for Clustering")
plt.grid(True)
plt.show()
# Out:
# Using adpative eps = 4.59e-09
# C:\Users\uqkmuroi\AppData\Local\Temp\ipykernel_35040\2403948979.py:94: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   vals = row[sample_cols].replace(0, np.nan)  # ignore zeros
#  Step  Cluster_ID                                                                           Merged_Cluster_1                                                                                                                                                     Merged_Cluster_2  Linkage_Distance  Num_Compounds
#     1           9                                                               [Sodium molybdate dihydrate]                                                                                                                                         [Iron sulphate heptahydrate]          0.063014              2
#     2          10                                                         [Cobalt (II) chloride hexahydrate]                                                                                                             [Sodium molybdate dihydrate, Iron sulphate heptahydrate]          0.098361              3
#     3          11                                                                     [Copper (II) sulphate]                                                                                                                                                   [Potassium iodide]          0.208932              2
#     4          12                                                        [Manganese (II) chloride dihydrate]                                                                                                                                    [Magnesium sulphate heptahydrate]          0.272340              2
#     5          13                                                               [Zinc sulphate heptahydrate]                                                                                                 [Manganese (II) chloride dihydrate, Magnesium sulphate heptahydrate]          0.471055              3
#     6          14                                                               [Calcium chloride dihydrate]                                                                     [Zinc sulphate heptahydrate, Manganese (II) chloride dihydrate, Magnesium sulphate heptahydrate]          0.986447              4
#     7          15                                                   [Copper (II) sulphate, Potassium iodide]                                         [Calcium chloride dihydrate, Zinc sulphate heptahydrate, Manganese (II) chloride dihydrate, Magnesium sulphate heptahydrate]          2.319486              6
#     8          16 [Cobalt (II) chloride hexahydrate, Sodium molybdate dihydrate, Iron sulphate heptahydrate] [Copper (II) sulphate, Potassium iodide, Calcium chloride dihydrate, Zinc sulphate heptahydrate, Manganese (II) chloride dihydrate, Magnesium sulphate heptahydrate]          2.548056              9

# %% [markdown]
# Vitamin hierarchical tree (same as above which was for elements)

# %%
# -------------------------------
# Step 0: Prepare data
# -------------------------------
df_v = yar_df_vitamin.copy()

df_v = df_v.sample(frac=1)  # shuffle rows for randomness
sample_cols = df_v.columns.difference(['Compound', 'Annotate'])



# Adaptive eps adds a small value based on the minimum non-zero value in the dataset
min_nonzero = df_v[sample_cols].replace(0, np.nan).min().min()
eps = min_nonzero*1e-3
# This prevents frac=1 from changing the clustering results
print(f"Using adpative eps = {eps:.2e}")

# -------------------------------
# Step 1: Compute log-ratio distances
# -------------------------------
ratios = []

# All unique compound pairs
compound_pairs = list(itertools.combinations(df_v['Compound'], 2))

# Map for quick lookup
compound_map = df_v.set_index('Compound')[sample_cols]

for c1, c2 in compound_pairs:
    vals1 = compound_map.loc[c1]
    vals2 = compound_map.loc[c2]

    # log-ratio with pseudocount
    ratio = np.log10(vals1 + eps) - np.log10(vals2 + eps)
    
    # absolute value (fold difference)
    ratio = ratio.abs()
    
    # if all NaN or zero, replace with small value to avoid exact zero distance
    if ratio.notna().sum() == 0:
        ratio[:] = eps

    row = {'Compound_1': c1, 'Compound_2': c2, **ratio.to_dict()}
    ratios.append(row)

ratio_df_v = pd.DataFrame(ratios)

# Drop irrelevant columns
ratio_df_v_reduced = ratio_df_v.drop(columns=['1_YAR','2b_YAR','2c_YAR','2d_YAR','3c_YAR','6_YAR'], errors='ignore')

# -------------------------------
# Step 2: Compute SD per pair
# -------------------------------
sample_cols = ratio_df_v_reduced.columns.difference(['Compound_1', 'Compound_2'])
ratio_df_v_reduced['Std_Ratio'] = ratio_df_v_reduced[sample_cols].replace(0, np.nan).std(axis=1, skipna=True).fillna(0)

# -------------------------------
# Step 3: Build distance matrix
# -------------------------------
compounds = pd.unique(ratio_df_v_reduced[['Compound_1', 'Compound_2']].values.ravel())
distance_matrix = pd.DataFrame(0, index=compounds, columns=compounds, dtype=float)

for _, row in ratio_df_v_reduced.iterrows():
    c1, c2, std = row['Compound_1'], row['Compound_2'], row['Std_Ratio']
    distance_matrix.loc[c1, c2] = std
    distance_matrix.loc[c2, c1] = std

np.fill_diagonal(distance_matrix.values, 0)

# -------------------------------
# Step 4: Hierarchical clustering
# -------------------------------
# Convert to condensed distance matrix
condensed_dist = squareform(distance_matrix.values)

# Use average linkage
Z = linkage(condensed_dist, method='average')

# -------------------------------
# Step 5: Plot dendrogram
# -------------------------------
plt.figure(figsize=(12, 6))
dendrogram(Z, labels=distance_matrix.index.tolist(), leaf_rotation=90)
plt.yscale('symlog', linthresh=.0001)
plt.ylabel("Linkage Distance (symlog)")
plt.title("Hierarchical Clustering of Compounds (Log-Ratio Std)")
plt.tight_layout()
plt.show()

'''Same thing as std above but for max-min range ratios'''
# -------------------------------
# Step 1: Compute max-min distances per pair
# -------------------------------
range_values = []

for _, row in ratio_df_v_reduced.iterrows():
    vals = row[sample_cols].replace(0, np.nan)  # ignore zeros
    if vals.notna().sum() == 0:
        rng = eps  # avoid NaNs and treats as small distance
    else:
        rng = vals.max() - vals.min()
        if rng == 0:
            rng = eps # gives tiny separation if all values are the same
    range_values.append(rng)

ratio_df_v_reduced['Range'] = range_values

# -------------------------------
# Step 2: Build distance matrix
# -------------------------------
distance_matrix_range = pd.DataFrame(0, index=compounds, columns=compounds, dtype=float)

for _, row in ratio_df_v_reduced.iterrows():
    c1, c2, rng = row['Compound_1'], row['Compound_2'], row['Range']
    distance_matrix_range.loc[c1, c2] = rng
    distance_matrix_range.loc[c2, c1] = rng

np.fill_diagonal(distance_matrix_range.values, 0)

# -------------------------------
# Step 3: Hierarchical clustering
# -------------------------------
condensed_dist_range = squareform(distance_matrix_range.values)
Z_range = linkage(condensed_dist_range, method='average')

# -------------------------------
# Step 4: Plot dendrogram
# -------------------------------
plt.figure(figsize=(12, 6))
dendrogram(Z_range, labels=distance_matrix_range.index.tolist(), leaf_rotation=90)
plt.yscale('symlog', linthresh=0.01)
plt.ylabel("Linkage Distance (max-min range)")
plt.title("Hierarchical Clustering of Compounds (Max-Min Range)")
plt.tight_layout()
plt.show()


'''this bit generates the merge table for the hierarchical clustering'''
# Get compound names
compounds = list(distance_matrix.index)

# Number of original observations
n = len(compounds)

# This will store merge history
merge_history = []

# Track cluster membership (compound names or merged groups)
clusters = {i: [compounds[i]] for i in range(n)}

# Loop over linkage matrix Z
for step, (idx1, idx2, dist, sample_count) in enumerate(Z):
    idx1, idx2 = int(idx1), int(idx2)
    
    # Get the clusters being merged
    members1 = clusters[idx1]
    members2 = clusters[idx2]

    # Merge the two clusters
    new_cluster = members1 + members2
    clusters[n + step] = new_cluster

    # Save merge info
    merge_history.append({
        'Step': step + 1,
        'Cluster_ID': n + step,
        'Merged_Cluster_1': members1,
        'Merged_Cluster_2': members2,
        'Linkage_Distance': dist,
        'Num_Compounds': len(new_cluster),
    })

# Convert to dataframe for easier viewing
merge_df = pd.DataFrame(merge_history)

# Display the merge table sorted by step (or by distance, if you prefer)
merge_df_sorted = merge_df.sort_values('Linkage_Distance', ascending=True)

# Print the table or write to CSV
print(merge_df_sorted.to_string(index=False))

merge_df_sorted[['Step', 'Linkage_Distance']].plot(x='Step', y='Linkage_Distance', marker='o')
plt.ylabel("Linkage Distance (range)")
plt.title("Elbow Plot for Clustering")
plt.grid(True)
plt.show()
# Out:
# Using adpative eps = 7.50e-11
# C:\Users\uqkmuroi\AppData\Local\Temp\ipykernel_35040\2545492560.py:96: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   vals = row[sample_cols].replace(0, np.nan)  # ignore zeros
#  Step  Cluster_ID                                                               Merged_Cluster_1                                                                                                         Merged_Cluster_2  Linkage_Distance  Num_Compounds
#     1           8                                                               [Pyridoxine-HCl]                                                                                                   [Calcium pantothenate]          0.000000              2
#     2           9                                                               [Nicotinic acid]                                                                                   [Pyridoxine-HCl, Calcium pantothenate]          0.000000              3
#     3          10                                                       [Thiamine hydrochloride]                                                                                                                 [Biotin]          0.106451              2
#     4          11                                                       [para-aminobenzoic acid]                                                                   [Nicotinic acid, Pyridoxine-HCl, Calcium pantothenate]          0.577350              4
#     5          12                                                                     [Inositol]                                                                                         [Thiamine hydrochloride, Biotin]          0.713836              3
#     6          13 [para-aminobenzoic acid, Nicotinic acid, Pyridoxine-HCl, Calcium pantothenate]                                                                               [Inositol, Thiamine hydrochloride, Biotin]          1.553061              7
#     7          14                                                                   [Boric acid] [para-aminobenzoic acid, Nicotinic acid, Pyridoxine-HCl, Calcium pantothenate, Inositol, Thiamine hydrochloride, Biotin]          3.381410              8

# %% [markdown]
# # Alpha generator 1.1 and tool for clustering reduction, converting between raw and transfored data, and generating BO boundaries
#
# ## Alpha generator has been updated to choose expanded min max bounds

# %%
class ClusterScaler:
    def __init__(self, df, cluster_compounds):
        """
        Args:
            df (pd.DataFrame): Must contain 'Compound', 'Min', 'Max', and 'Median' columns
            cluster_compounds (list of str): List of compounds to include in this cluster
        """
        self.df = df.set_index("Compound")
        self.compounds = cluster_compounds

        # Pull stats
        self.medians = self.df.loc[self.compounds, "Median"].to_dict()

        # use expaned bounds if available, otherwise use original min/max
        if 'Expanded_Min' in self.df.columns and 'Expanded_Max' in self.df.columns:
            self.mins = self.df.loc[self.compounds, "Expanded_Min"].to_dict()
            self.maxs = self.df.loc[self.compounds, "Expanded_Max"].to_dict()
        else:
            self.mins = self.df.loc[self.compounds, "Min"].to_dict()
            self.maxs = self.df.loc[self.compounds, "Max"].to_dict()

        # Log10 of medians
        self.log10_medians = {k: np.log10(v) for k, v in self.medians.items()}
        self.mean_log10 = np.mean(list(self.log10_medians.values()))

        # Offsets c_i
        self.offsets = {k: v - self.mean_log10 for k, v in self.log10_medians.items()}

    def log_concentration_from_alpha(self, alpha):
        return {compound: alpha + offset for compound, offset in self.offsets.items()}

    def concentration_from_alpha(self, alpha):
        return {compound: 10**(alpha + offset) for compound, offset in self.offsets.items()}

    def solve_alpha_for_target(self, compound, target_concentration):
        if compound not in self.offsets:
            raise ValueError(f"Compound '{compound}' not in this cluster.")
        return np.log10(target_concentration) - self.offsets[compound]

    def get_alpha_bounds(self):
        alpha_mins = []
        alpha_maxs = []

        for compound in self.compounds:
            c_i = self.offsets[compound]
            min_val = self.mins[compound]
            max_val = self.maxs[compound]
            alpha_min_i = np.log10(min_val) - c_i
            alpha_max_i = np.log10(max_val) - c_i
            alpha_mins.append(alpha_min_i)
            alpha_maxs.append(alpha_max_i)

        alpha_min = min(alpha_mins)
        alpha_max = max(alpha_maxs)

        if alpha_min > alpha_max:
            raise ValueError("No valid alpha range — bounds conflict between compounds.")

        return alpha_min, alpha_max

# %%
# this allows for min max range extraction for elements and vitamins for the plots below
df_e_reduced = df_e.drop(columns = ['1_YAR', '2b_YAR', '2c_YAR', '2d_YAR', '3b_YAR', '3c_YAR', '6_YAR']) 

df_e_reduced_nan = df_e_reduced.replace(0, np.nan) # replace 0 with Nans so correct min can be extracted
#selects numeric columns only
numeric_cols_e = df_e_reduced_nan.select_dtypes(include=[np.number]).columns


# Compute min and max for each compound, excluding NaNs
min_values = df_e_reduced_nan[numeric_cols_e].min(axis=1, skipna=True)
max_values = df_e_reduced_nan[numeric_cols_e].max(axis=1, skipna=True)
median_values = df_e_reduced_nan[numeric_cols_e].median(axis=1, skipna = True)
mean_values = df_e_reduced_nan[numeric_cols_e].mean(axis=1, skipna = True)

# Create a new dataframe with Compound, Min, and Max
df_e_min_max = pd.DataFrame({
    'Compound': df_e_reduced_nan['Compound'],
    'Min': min_values,
    'Max': max_values,
    'Median': median_values,
    'Mean': mean_values
})

# ========== Vitamin section below ==========

df_v_reduced = df_v.drop(columns=['1_YAR','2b_YAR', '2c_YAR', '2d_YAR', '3c_YAR', '6_YAR'])

df_v_reduced_nan = df_v_reduced.replace(0, np.nan) # replace 0 with Nans so correct min can be extracted

#selects numeric columns only
numeric_cols_v = df_v_reduced_nan.select_dtypes(include=[np.number]).columns

# Compute min and max for each compound, excluding NaNs
min_values = df_v_reduced_nan[numeric_cols_v].min(axis=1, skipna=True)
max_values = df_v_reduced_nan[numeric_cols_v].max(axis=1, skipna=True)
median_values = df_v_reduced_nan[numeric_cols_v].median(axis=1, skipna = True)
mean_values = df_v_reduced_nan[numeric_cols_v].mean(axis=1, skipna = True)

# Create a new dataframe with Compound, Min, and Max
df_v_min_max = pd.DataFrame({
    'Compound': df_v_reduced_nan['Compound'],
    'Min': min_values,
    'Max': max_values,
    'Median': median_values,
    'Mean': mean_values
})

# %%
def expand_bounds(min_val, max_val, percent=0.1):
    expanded_min = min_val / (1 + percent)
    expanded_max = max_val * (1 + percent)
    return expanded_min, expanded_max


# Apply the expansion row-wise

df_e_min_max[['Expanded_Min', 'Expanded_Max']] = df_e_min_max.apply(
    lambda row: pd.Series(expand_bounds(row['Min'], row['Max'])),
    axis=1
)

df_v_min_max[['Expanded_Min', 'Expanded_Max']] = df_v_min_max.apply(
    lambda row: pd.Series(expand_bounds(row['Min'], row['Max'])),
    axis=1
)

# %%
df_all = pd.concat([df_v_min_max, df_e_min_max], ignore_index=True)
# Sort compounds by median or mean for clean axis ordering
df_sorted = df_all#.sort_values(by='Median')

plt.figure(figsize=(14, 6))

for i, row in enumerate(df_sorted.itertuples()):
    y = i
    
    # Plot original Min–Max as a narrow line
    plt.plot([row.Min, row.Max], [y, y], color='black', lw=1.5, label='Min–Max' if i == 0 else "")

    # Plot expanded range as a thick semi-transparent bar
    plt.plot([row.Expanded_Min, row.Expanded_Max], [y, y], color='skyblue', lw=6, alpha=0.4, label='Expanded Range' if i == 0 else "")
    
    # Mark median and mean
    plt.plot(row.Median, y, 'o', color='green', label='Median' if i == 0 else "")
    plt.plot(row.Mean, y, 'x', color='orange', label='Mean' if i == 0 else "")

plt.yticks(range(len(df_sorted)), df_sorted['Compound'])
plt.xlabel("Concentration")
plt.title("Compound Concentration Ranges and Summary Statistics")
plt.legend(loc='upper right')
plt.xscale('log')  # for comparability across orders of magnitude
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
# cluster order here is arbitrary, but we want separate scalers for conversion when transforming data

#This is the old clusters before Haxby found some flaws in the code
'''
cluster_e1 = ['Copper (II) sulphate pentahydrate', 'Manganese chloride tetrahydrate']
scaler_e1 = ClusterScaler(df_e_min_max, cluster_e1)

cluster_e2 = ['Cobalt (II) chloride hexahydrate', 'Iron sulphate heptahydrate', 'Potassium iodide']
scaler_e2 = ClusterScaler(df_e_min_max, cluster_e2)

cluster_e3 = ['Magnesium sulphate heptahydrate', 'Sodium molybdate dihydrate', 'Zinc sulphate heptahydrate']
scaler_e3 = ClusterScaler(df_e_min_max, cluster_e3)

cluster_v1 = ['Nicotinic acid', 'Boric acid', 'Calcium pantothenate']
scaler_v1 = ClusterScaler(df_v_min_max, cluster_v1)

cluster_v2 = ['Biotin', 'Pyridoxine']
scaler_v2 = ClusterScaler(df_v_min_max, cluster_v2)
'''

# ---------------- Elements ----------------
cluster_e1 = ['Potassium iodide', 'Copper (II) sulphate']
scaler_e1 = ClusterScaler(df_e_min_max, cluster_e1)

cluster_e2 = ['Iron sulphate heptahydrate', 'Sodium molybdate dihydrate', 'Cobalt (II) chloride hexahydrate']
scaler_e2 = ClusterScaler(df_e_min_max, cluster_e2)

cluster_e3 = ['Magnesium sulphate heptahydrate', 'Manganese (II) chloride dihydrate']#, 'Zinc sulphate heptahydrate']#, 'Calcium chloride dihydrate']
scaler_e3 = ClusterScaler(df_e_min_max, cluster_e3)

# ---------------- Vitamins ----------------
cluster_v1 = ['Nicotinic acid', 'Calcium pantothenate', 'Pyridoxine-HCl']
scaler_v1 = ClusterScaler(df_v_min_max, cluster_v1)

cluster_v2 = ['Biotin', 'Thiamine hydrochloride']#, 'Inositol']
scaler_v2 = ClusterScaler(df_v_min_max, cluster_v2)

# %%
# Step 1: Name your clusters
named_clusters = {
    "cluster_e1": cluster_e1,
    "cluster_e2": cluster_e2,
    "cluster_e3": cluster_e3,
    "cluster_v1": cluster_v1,
    "cluster_v2": cluster_v2,
}

scaler_map = {
    "cluster_e1": scaler_e1,
    "cluster_e2": scaler_e2,
    "cluster_e3": scaler_e3,
    "cluster_v1": scaler_v1,
    "cluster_v2": scaler_v2,
}

# Step 2: Collect all clustered compounds
clustered_compounds = sum(named_clusters.values(), [])  # flatten list of lists

# Step 3: Get bounds for non-clustered compounds
non_cluster_e = df_e_min_max[~df_e_min_max['Compound'].isin(clustered_compounds)]
non_cluster_v = df_v_min_max[~df_v_min_max['Compound'].isin(clustered_compounds)]

non_cluster_bounds = dict(
    zip(
        non_cluster_e['Compound'].tolist() + non_cluster_v['Compound'].tolist(),
        list(non_cluster_e[['Expanded_Min', 'Expanded_Max']].itertuples(index=False, name=None)) +
        list(non_cluster_v[['Expanded_Min', 'Expanded_Max']].itertuples(index=False, name=None))
    )
)

# Step 4: Get alpha bounds for each cluster
cluster_bounds = {
    cluster_name: scaler_map[cluster_name].get_alpha_bounds()
    for cluster_name in named_clusters
}

# Step 5: log-transform non-cluster compounds (so BO bounds can be generated from them (we can easily tranform back))
non_cluster_bounds_log = {
    compound: (np.log10(lo), np.log10(hi))
    for compound, (lo, hi) in non_cluster_bounds.items()
}

# Step 6: Combine
bo_bounds = {
    **cluster_bounds,           # alpha values, already log-based
    **non_cluster_bounds_log    # log-transformed non-clustered compounds
}

# %%
print(bo_bounds)
# Out:
# {'cluster_e1': (np.float64(-4.687029308505964), np.float64(-3.6042422396134266)), 'cluster_e2': (np.float64(-3.1892918515691293), np.float64(-2.5135898693645857)), 'cluster_e3': (np.float64(-2.046754617854112), np.float64(-1.351185390817926)), 'cluster_v1': (np.float64(-3.342422680822206), np.float64(-2.7825160557860937)), 'cluster_v2': (np.float64(-4.642181987721351), np.float64(-3.433031053618084)), 'Zinc sulphate heptahydrate': (np.float64(-3.439332693830263), np.float64(-1.80099946148011)), 'Calcium chloride dihydrate': (np.float64(-2.5614162301685997), np.float64(-0.8365051577342866)), 'Inositol': (np.float64(-5.740362689494244), np.float64(-1.384576047114056)), 'para-aminobenzoic acid': (np.float64(-4.564271430438563), np.float64(-3.657577319177794)), 'Boric acid': (np.float64(-3.342422680822206), np.float64(-2.657577319177794))}

# %% [markdown]
# ## We have generated the boundaries for bayesian optimisation
#
# Now we want to use these boundaries to generate a set of initial experiments.

# %%
# Step 1: Extract lower and upper bounds from bo_bounds
keys = list(bo_bounds.keys())  # Ordered list of compound or cluster names
dim_names = keys  # This matches the LHS columns
bounds_array = [bo_bounds[k] for k in keys]  # List of (min, max) tuples

# Step 2: Convert to torch.tensor
bounds = torch.tensor(bounds_array, dtype=torch.double)  # Shape: [d, 2]

# Step 3: Transpose to match expected shape [2, d]
bounds = bounds.T  # Now bounds[0] is lower, bounds[1] is upper

# Step 4: Get dimensionality
dim = bounds.shape[1]

# Step 5: Generate LHS samples
lhs_design = torch.tensor(
    lhs(n=dim, samples=191, criterion='maximin', random_state=42),
    dtype=torch.double
)

# Step 6: Scale LHS into the specified bounds
scaled_lhs_design = bounds[0] + (bounds[1] - bounds[0]) * lhs_design

# %%
def decode_bo_sample(sample, keys, scalers, df_min_max):
    """
    Args:
        sample (np.ndarray or torch): shape (d,)
        keys (list): names of each variable (cluster name or compound)
        scalers (dict): mapping from cluster_name → ClusterScaler
        df_min_max (DataFrame): has Expanded_Min for all compounds

    Returns:
        dict: compound → concentration (linear)
    """
    if isinstance(sample, torch.Tensor):
        sample = sample.detach().cpu().numpy()

    output = {}

    for value, key in zip(sample, keys):
        if key.startswith("cluster"):
            # Cluster: use alpha → get all compound concentrations
            cluster_scaler = scalers[key]
            conc_dict = cluster_scaler.concentration_from_alpha(value)
            output.update(conc_dict)
        else:
            # Individual compound: interpret value as log10(conc)
            conc = 10**value
            output[key] = conc

    return output

# %%
# Let's say lhs_design is (n_samples × d)
for i in range(lhs_design.shape[0]):
    raw_point = scaled_lhs_design[i, :]
    decoded = decode_bo_sample(
        raw_point,
        keys=list(bo_bounds.keys()),
        scalers=scaler_map,  # same dict from earlier: "cluster_v1" → scaler
        df_min_max=pd.concat([df_e_min_max, df_v_min_max])
    )
    print(f"Sample {i}:")
    for k, v in decoded.items():
        print(f"  {k}: {v:.5f} g/L")
# Out:
# Sample 0:
#   Potassium iodide: 0.00014 g/L
#   Copper (II) sulphate: 0.00018 g/L
#   Iron sulphate heptahydrate: 0.00998 g/L
#   Sodium molybdate dihydrate: 0.00133 g/L
#   Cobalt (II) chloride hexahydrate: 0.00100 g/L
#   Magnesium sulphate heptahydrate: 0.91606 g/L
#   Manganese (II) chloride dihydrate: 0.00150 g/L
#   Nicotinic acid: 0.00062 g/L
#   Calcium pantothenate: 0.00062 g/L
#   Pyridoxine-HCl: 0.00062 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00034 g/L
#   Zinc sulphate heptahydrate: 0.00469 g/L
#   Calcium chloride dihydrate: 0.00343 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00012 g/L
#   Boric acid: 0.00107 g/L
# Sample 1:
#   Potassium iodide: 0.00008 g/L
#   Copper (II) sulphate: 0.00010 g/L
#   Iron sulphate heptahydrate: 0.00941 g/L
#   Sodium molybdate dihydrate: 0.00125 g/L
#   Cobalt (II) chloride hexahydrate: 0.00094 g/L
#   Magnesium sulphate heptahydrate: 0.44680 g/L
#   Manganese (II) chloride dihydrate: 0.00073 g/L
#   Nicotinic acid: 0.00059 g/L
#   Calcium pantothenate: 0.00059 g/L
#   Pyridoxine-HCl: 0.00059 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00035 g/L
#   Zinc sulphate heptahydrate: 0.00102 g/L
#   Calcium chloride dihydrate: 0.03163 g/L
#   Inositol: 0.00008 g/L
#   para-aminobenzoic acid: 0.00007 g/L
#   Boric acid: 0.00094 g/L
# Sample 2:
#   Potassium iodide: 0.00005 g/L
#   Copper (II) sulphate: 0.00006 g/L
#   Iron sulphate heptahydrate: 0.00635 g/L
#   Sodium molybdate dihydrate: 0.00085 g/L
#   Cobalt (II) chloride hexahydrate: 0.00063 g/L
#   Magnesium sulphate heptahydrate: 0.74380 g/L
#   Manganese (II) chloride dihydrate: 0.00122 g/L
#   Nicotinic acid: 0.00154 g/L
#   Calcium pantothenate: 0.00154 g/L
#   Pyridoxine-HCl: 0.00154 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00032 g/L
#   Zinc sulphate heptahydrate: 0.01529 g/L
#   Calcium chloride dihydrate: 0.00400 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00021 g/L
#   Boric acid: 0.00067 g/L
# Sample 3:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00908 g/L
#   Sodium molybdate dihydrate: 0.00121 g/L
#   Cobalt (II) chloride hexahydrate: 0.00091 g/L
#   Magnesium sulphate heptahydrate: 0.77475 g/L
#   Manganese (II) chloride dihydrate: 0.00127 g/L
#   Nicotinic acid: 0.00103 g/L
#   Calcium pantothenate: 0.00103 g/L
#   Pyridoxine-HCl: 0.00103 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00015 g/L
#   Zinc sulphate heptahydrate: 0.00139 g/L
#   Calcium chloride dihydrate: 0.04088 g/L
#   Inositol: 0.00006 g/L
#   para-aminobenzoic acid: 0.00008 g/L
#   Boric acid: 0.00086 g/L
# Sample 4:
#   Potassium iodide: 0.00011 g/L
#   Copper (II) sulphate: 0.00014 g/L
#   Iron sulphate heptahydrate: 0.01070 g/L
#   Sodium molybdate dihydrate: 0.00143 g/L
#   Cobalt (II) chloride hexahydrate: 0.00107 g/L
#   Magnesium sulphate heptahydrate: 0.70404 g/L
#   Manganese (II) chloride dihydrate: 0.00115 g/L
#   Nicotinic acid: 0.00109 g/L
#   Calcium pantothenate: 0.00109 g/L
#   Pyridoxine-HCl: 0.00109 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00016 g/L
#   Zinc sulphate heptahydrate: 0.00553 g/L
#   Calcium chloride dihydrate: 0.01825 g/L
#   Inositol: 0.00032 g/L
#   para-aminobenzoic acid: 0.00019 g/L
#   Boric acid: 0.00096 g/L
# Sample 5:
#   Potassium iodide: 0.00011 g/L
#   Copper (II) sulphate: 0.00014 g/L
#   Iron sulphate heptahydrate: 0.00688 g/L
#   Sodium molybdate dihydrate: 0.00092 g/L
#   Cobalt (II) chloride hexahydrate: 0.00069 g/L
#   Magnesium sulphate heptahydrate: 0.98619 g/L
#   Manganese (II) chloride dihydrate: 0.00162 g/L
#   Nicotinic acid: 0.00061 g/L
#   Calcium pantothenate: 0.00061 g/L
#   Pyridoxine-HCl: 0.00061 g/L
#   Biotin: 0.00003 g/L
#   Thiamine hydrochloride: 0.00050 g/L
#   Zinc sulphate heptahydrate: 0.00794 g/L
#   Calcium chloride dihydrate: 0.00348 g/L
#   Inositol: 0.00066 g/L
#   para-aminobenzoic acid: 0.00007 g/L
#   Boric acid: 0.00138 g/L
# Sample 6:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00958 g/L
#   Sodium molybdate dihydrate: 0.00128 g/L
#   Cobalt (II) chloride hexahydrate: 0.00096 g/L
#   Magnesium sulphate heptahydrate: 0.44179 g/L
#   Manganese (II) chloride dihydrate: 0.00072 g/L
#   Nicotinic acid: 0.00134 g/L
#   Calcium pantothenate: 0.00134 g/L
#   Pyridoxine-HCl: 0.00134 g/L
#   Biotin: 0.00005 g/L
#   Thiamine hydrochloride: 0.00103 g/L
#   Zinc sulphate heptahydrate: 0.00264 g/L
#   Calcium chloride dihydrate: 0.12152 g/L
#   Inositol: 0.00002 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00135 g/L
# Sample 7:
#   Potassium iodide: 0.00010 g/L
#   Copper (II) sulphate: 0.00013 g/L
#   Iron sulphate heptahydrate: 0.00315 g/L
#   Sodium molybdate dihydrate: 0.00042 g/L
#   Cobalt (II) chloride hexahydrate: 0.00032 g/L
#   Magnesium sulphate heptahydrate: 0.26486 g/L
#   Manganese (II) chloride dihydrate: 0.00043 g/L
#   Nicotinic acid: 0.00058 g/L
#   Calcium pantothenate: 0.00058 g/L
#   Pyridoxine-HCl: 0.00058 g/L
#   Biotin: 0.00003 g/L
#   Thiamine hydrochloride: 0.00060 g/L
#   Zinc sulphate heptahydrate: 0.00675 g/L
#   Calcium chloride dihydrate: 0.10196 g/L
#   Inositol: 0.00041 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00071 g/L
# Sample 8:
#   Potassium iodide: 0.00010 g/L
#   Copper (II) sulphate: 0.00012 g/L
#   Iron sulphate heptahydrate: 0.00437 g/L
#   Sodium molybdate dihydrate: 0.00058 g/L
#   Cobalt (II) chloride hexahydrate: 0.00044 g/L
#   Magnesium sulphate heptahydrate: 0.78477 g/L
#   Manganese (II) chloride dihydrate: 0.00129 g/L
#   Nicotinic acid: 0.00125 g/L
#   Calcium pantothenate: 0.00125 g/L
#   Pyridoxine-HCl: 0.00125 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00023 g/L
#   Zinc sulphate heptahydrate: 0.00179 g/L
#   Calcium chloride dihydrate: 0.07842 g/L
#   Inositol: 0.00101 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00149 g/L
# Sample 9:
#   Potassium iodide: 0.00015 g/L
#   Copper (II) sulphate: 0.00019 g/L
#   Iron sulphate heptahydrate: 0.00702 g/L
#   Sodium molybdate dihydrate: 0.00094 g/L
#   Cobalt (II) chloride hexahydrate: 0.00070 g/L
#   Magnesium sulphate heptahydrate: 0.38661 g/L
#   Manganese (II) chloride dihydrate: 0.00063 g/L
#   Nicotinic acid: 0.00047 g/L
#   Calcium pantothenate: 0.00047 g/L
#   Pyridoxine-HCl: 0.00047 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00025 g/L
#   Zinc sulphate heptahydrate: 0.00152 g/L
#   Calcium chloride dihydrate: 0.03276 g/L
#   Inositol: 0.00007 g/L
#   para-aminobenzoic acid: 0.00008 g/L
#   Boric acid: 0.00047 g/L
# Sample 10:
#   Potassium iodide: 0.00009 g/L
#   Copper (II) sulphate: 0.00011 g/L
#   Iron sulphate heptahydrate: 0.00501 g/L
#   Sodium molybdate dihydrate: 0.00067 g/L
#   Cobalt (II) chloride hexahydrate: 0.00050 g/L
#   Magnesium sulphate heptahydrate: 0.73103 g/L
#   Manganese (II) chloride dihydrate: 0.00120 g/L
#   Nicotinic acid: 0.00062 g/L
#   Calcium pantothenate: 0.00062 g/L
#   Pyridoxine-HCl: 0.00062 g/L
#   Biotin: 0.00006 g/L
#   Thiamine hydrochloride: 0.00118 g/L
#   Zinc sulphate heptahydrate: 0.00088 g/L
#   Calcium chloride dihydrate: 0.08326 g/L
#   Inositol: 0.01893 g/L
#   para-aminobenzoic acid: 0.00014 g/L
#   Boric acid: 0.00109 g/L
# Sample 11:
#   Potassium iodide: 0.00018 g/L
#   Copper (II) sulphate: 0.00023 g/L
#   Iron sulphate heptahydrate: 0.00923 g/L
#   Sodium molybdate dihydrate: 0.00123 g/L
#   Cobalt (II) chloride hexahydrate: 0.00092 g/L
#   Magnesium sulphate heptahydrate: 0.24130 g/L
#   Manganese (II) chloride dihydrate: 0.00040 g/L
#   Nicotinic acid: 0.00101 g/L
#   Calcium pantothenate: 0.00101 g/L
#   Pyridoxine-HCl: 0.00101 g/L
#   Biotin: 0.00004 g/L
#   Thiamine hydrochloride: 0.00072 g/L
#   Zinc sulphate heptahydrate: 0.00043 g/L
#   Calcium chloride dihydrate: 0.08298 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00012 g/L
#   Boric acid: 0.00061 g/L
# Sample 12:
#   Potassium iodide: 0.00005 g/L
#   Copper (II) sulphate: 0.00007 g/L
#   Iron sulphate heptahydrate: 0.00761 g/L
#   Sodium molybdate dihydrate: 0.00101 g/L
#   Cobalt (II) chloride hexahydrate: 0.00076 g/L
#   Magnesium sulphate heptahydrate: 0.34026 g/L
#   Manganese (II) chloride dihydrate: 0.00056 g/L
#   Nicotinic acid: 0.00054 g/L
#   Calcium pantothenate: 0.00054 g/L
#   Pyridoxine-HCl: 0.00054 g/L
#   Biotin: 0.00006 g/L
#   Thiamine hydrochloride: 0.00111 g/L
#   Zinc sulphate heptahydrate: 0.00773 g/L
#   Calcium chloride dihydrate: 0.02049 g/L
#   Inositol: 0.00153 g/L
#   para-aminobenzoic acid: 0.00015 g/L
#   Boric acid: 0.00049 g/L
# Sample 13:
#   Potassium iodide: 0.00008 g/L
#   Copper (II) sulphate: 0.00010 g/L
#   Iron sulphate heptahydrate: 0.00512 g/L
#   Sodium molybdate dihydrate: 0.00068 g/L
#   Cobalt (II) chloride hexahydrate: 0.00051 g/L
#   Magnesium sulphate heptahydrate: 0.43478 g/L
#   Manganese (II) chloride dihydrate: 0.00071 g/L
#   Nicotinic acid: 0.00066 g/L
#   Calcium pantothenate: 0.00066 g/L
#   Pyridoxine-HCl: 0.00066 g/L
#   Biotin: 0.00003 g/L
#   Thiamine hydrochloride: 0.00066 g/L
#   Zinc sulphate heptahydrate: 0.00163 g/L
#   Calcium chloride dihydrate: 0.00369 g/L
#   Inositol: 0.01491 g/L
#   para-aminobenzoic acid: 0.00006 g/L
#   Boric acid: 0.00151 g/L
# Sample 14:
#   Potassium iodide: 0.00019 g/L
#   Copper (II) sulphate: 0.00025 g/L
#   Iron sulphate heptahydrate: 0.01222 g/L
#   Sodium molybdate dihydrate: 0.00163 g/L
#   Cobalt (II) chloride hexahydrate: 0.00122 g/L
#   Magnesium sulphate heptahydrate: 0.43769 g/L
#   Manganese (II) chloride dihydrate: 0.00072 g/L
#   Nicotinic acid: 0.00082 g/L
#   Calcium pantothenate: 0.00082 g/L
#   Pyridoxine-HCl: 0.00082 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00013 g/L
#   Zinc sulphate heptahydrate: 0.00096 g/L
#   Calcium chloride dihydrate: 0.08725 g/L
#   Inositol: 0.00650 g/L
#   para-aminobenzoic acid: 0.00017 g/L
#   Boric acid: 0.00170 g/L
# Sample 15:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00005 g/L
#   Iron sulphate heptahydrate: 0.00539 g/L
#   Sodium molybdate dihydrate: 0.00072 g/L
#   Cobalt (II) chloride hexahydrate: 0.00054 g/L
#   Magnesium sulphate heptahydrate: 0.53355 g/L
#   Manganese (II) chloride dihydrate: 0.00088 g/L
#   Nicotinic acid: 0.00071 g/L
#   Calcium pantothenate: 0.00071 g/L
#   Pyridoxine-HCl: 0.00071 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00011 g/L
#   Zinc sulphate heptahydrate: 0.00959 g/L
#   Calcium chloride dihydrate: 0.01207 g/L
#   Inositol: 0.00071 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00210 g/L
# Sample 16:
#   Potassium iodide: 0.00020 g/L
#   Copper (II) sulphate: 0.00025 g/L
#   Iron sulphate heptahydrate: 0.00482 g/L
#   Sodium molybdate dihydrate: 0.00064 g/L
#   Cobalt (II) chloride hexahydrate: 0.00048 g/L
#   Magnesium sulphate heptahydrate: 0.96550 g/L
#   Manganese (II) chloride dihydrate: 0.00158 g/L
#   Nicotinic acid: 0.00113 g/L
#   Calcium pantothenate: 0.00113 g/L
#   Pyridoxine-HCl: 0.00113 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00048 g/L
#   Zinc sulphate heptahydrate: 0.00063 g/L
#   Calcium chloride dihydrate: 0.01122 g/L
#   Inositol: 0.03843 g/L
#   para-aminobenzoic acid: 0.00011 g/L
#   Boric acid: 0.00172 g/L
# Sample 17:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00720 g/L
#   Sodium molybdate dihydrate: 0.00096 g/L
#   Cobalt (II) chloride hexahydrate: 0.00072 g/L
#   Magnesium sulphate heptahydrate: 0.33950 g/L
#   Manganese (II) chloride dihydrate: 0.00056 g/L
#   Nicotinic acid: 0.00063 g/L
#   Calcium pantothenate: 0.00063 g/L
#   Pyridoxine-HCl: 0.00063 g/L
#   Biotin: 0.00008 g/L
#   Thiamine hydrochloride: 0.00152 g/L
#   Zinc sulphate heptahydrate: 0.01386 g/L
#   Calcium chloride dihydrate: 0.00772 g/L
#   Inositol: 0.00586 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00075 g/L
# Sample 18:
#   Potassium iodide: 0.00012 g/L
#   Copper (II) sulphate: 0.00015 g/L
#   Iron sulphate heptahydrate: 0.00452 g/L
#   Sodium molybdate dihydrate: 0.00060 g/L
#   Cobalt (II) chloride hexahydrate: 0.00045 g/L
#   Magnesium sulphate heptahydrate: 0.51424 g/L
#   Manganese (II) chloride dihydrate: 0.00084 g/L
#   Nicotinic acid: 0.00119 g/L
#   Calcium pantothenate: 0.00119 g/L
#   Pyridoxine-HCl: 0.00119 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00038 g/L
#   Zinc sulphate heptahydrate: 0.00078 g/L
#   Calcium chloride dihydrate: 0.00328 g/L
#   Inositol: 0.00998 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00200 g/L
# Sample 19:
#   Potassium iodide: 0.00017 g/L
#   Copper (II) sulphate: 0.00022 g/L
#   Iron sulphate heptahydrate: 0.00310 g/L
#   Sodium molybdate dihydrate: 0.00041 g/L
#   Cobalt (II) chloride hexahydrate: 0.00031 g/L
#   Magnesium sulphate heptahydrate: 0.36442 g/L
#   Manganese (II) chloride dihydrate: 0.00060 g/L
#   Nicotinic acid: 0.00078 g/L
#   Calcium pantothenate: 0.00078 g/L
#   Pyridoxine-HCl: 0.00078 g/L
#   Biotin: 0.00007 g/L
#   Thiamine hydrochloride: 0.00134 g/L
#   Zinc sulphate heptahydrate: 0.00157 g/L
#   Calcium chloride dihydrate: 0.10782 g/L
#   Inositol: 0.00062 g/L
#   para-aminobenzoic acid: 0.00012 g/L
#   Boric acid: 0.00159 g/L
# Sample 20:
#   Potassium iodide: 0.00006 g/L
#   Copper (II) sulphate: 0.00007 g/L
#   Iron sulphate heptahydrate: 0.00933 g/L
#   Sodium molybdate dihydrate: 0.00124 g/L
#   Cobalt (II) chloride hexahydrate: 0.00093 g/L
#   Magnesium sulphate heptahydrate: 0.54272 g/L
#   Manganese (II) chloride dihydrate: 0.00089 g/L
#   Nicotinic acid: 0.00050 g/L
#   Calcium pantothenate: 0.00050 g/L
#   Pyridoxine-HCl: 0.00050 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00027 g/L
#   Zinc sulphate heptahydrate: 0.00258 g/L
#   Calcium chloride dihydrate: 0.06686 g/L
#   Inositol: 0.00025 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00055 g/L
# Sample 21:
#   Potassium iodide: 0.00006 g/L
#   Copper (II) sulphate: 0.00007 g/L
#   Iron sulphate heptahydrate: 0.00286 g/L
#   Sodium molybdate dihydrate: 0.00038 g/L
#   Cobalt (II) chloride hexahydrate: 0.00029 g/L
#   Magnesium sulphate heptahydrate: 0.49836 g/L
#   Manganese (II) chloride dihydrate: 0.00082 g/L
#   Nicotinic acid: 0.00071 g/L
#   Calcium pantothenate: 0.00071 g/L
#   Pyridoxine-HCl: 0.00071 g/L
#   Biotin: 0.00003 g/L
#   Thiamine hydrochloride: 0.00056 g/L
#   Zinc sulphate heptahydrate: 0.00125 g/L
#   Calcium chloride dihydrate: 0.00797 g/L
#   Inositol: 0.00197 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00162 g/L
# Sample 22:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00580 g/L
#   Sodium molybdate dihydrate: 0.00077 g/L
#   Cobalt (II) chloride hexahydrate: 0.00058 g/L
#   Magnesium sulphate heptahydrate: 0.29947 g/L
#   Manganese (II) chloride dihydrate: 0.00049 g/L
#   Nicotinic acid: 0.00109 g/L
#   Calcium pantothenate: 0.00109 g/L
#   Pyridoxine-HCl: 0.00109 g/L
#   Biotin: 0.00008 g/L
#   Thiamine hydrochloride: 0.00151 g/L
#   Zinc sulphate heptahydrate: 0.00942 g/L
#   Calcium chloride dihydrate: 0.00563 g/L
#   Inositol: 0.00015 g/L
#   para-aminobenzoic acid: 0.00011 g/L
#   Boric acid: 0.00059 g/L
# Sample 23:
#   Potassium iodide: 0.00007 g/L
#   Copper (II) sulphate: 0.00008 g/L
#   Iron sulphate heptahydrate: 0.00391 g/L
#   Sodium molybdate dihydrate: 0.00052 g/L
#   Cobalt (II) chloride hexahydrate: 0.00039 g/L
#   Magnesium sulphate heptahydrate: 0.76754 g/L
#   Manganese (II) chloride dihydrate: 0.00126 g/L
#   Nicotinic acid: 0.00133 g/L
#   Calcium pantothenate: 0.00133 g/L
#   Pyridoxine-HCl: 0.00133 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00016 g/L
#   Zinc sulphate heptahydrate: 0.01247 g/L
#   Calcium chloride dihydrate: 0.04641 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00130 g/L
# Sample 24:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00002 g/L
#   Iron sulphate heptahydrate: 0.00439 g/L
#   Sodium molybdate dihydrate: 0.00059 g/L
#   Cobalt (II) chloride hexahydrate: 0.00044 g/L
#   Magnesium sulphate heptahydrate: 0.92912 g/L
#   Manganese (II) chloride dihydrate: 0.00152 g/L
#   Nicotinic acid: 0.00074 g/L
#   Calcium pantothenate: 0.00074 g/L
#   Pyridoxine-HCl: 0.00074 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00031 g/L
#   Zinc sulphate heptahydrate: 0.00040 g/L
#   Calcium chloride dihydrate: 0.03622 g/L
#   Inositol: 0.00046 g/L
#   para-aminobenzoic acid: 0.00012 g/L
#   Boric acid: 0.00063 g/L
# Sample 25:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00288 g/L
#   Sodium molybdate dihydrate: 0.00038 g/L
#   Cobalt (II) chloride hexahydrate: 0.00029 g/L
#   Magnesium sulphate heptahydrate: 0.31604 g/L
#   Manganese (II) chloride dihydrate: 0.00052 g/L
#   Nicotinic acid: 0.00162 g/L
#   Calcium pantothenate: 0.00162 g/L
#   Pyridoxine-HCl: 0.00162 g/L
#   Biotin: 0.00003 g/L
#   Thiamine hydrochloride: 0.00065 g/L
#   Zinc sulphate heptahydrate: 0.00070 g/L
#   Calcium chloride dihydrate: 0.00543 g/L
#   Inositol: 0.00004 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00054 g/L
# Sample 26:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00351 g/L
#   Sodium molybdate dihydrate: 0.00047 g/L
#   Cobalt (II) chloride hexahydrate: 0.00035 g/L
#   Magnesium sulphate heptahydrate: 0.87139 g/L
#   Manganese (II) chloride dihydrate: 0.00143 g/L
#   Nicotinic acid: 0.00060 g/L
#   Calcium pantothenate: 0.00060 g/L
#   Pyridoxine-HCl: 0.00060 g/L
#   Biotin: 0.00008 g/L
#   Thiamine hydrochloride: 0.00156 g/L
#   Zinc sulphate heptahydrate: 0.00079 g/L
#   Calcium chloride dihydrate: 0.07365 g/L
#   Inositol: 0.00008 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00059 g/L
# Sample 27:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00478 g/L
#   Sodium molybdate dihydrate: 0.00064 g/L
#   Cobalt (II) chloride hexahydrate: 0.00048 g/L
#   Magnesium sulphate heptahydrate: 0.42704 g/L
#   Manganese (II) chloride dihydrate: 0.00070 g/L
#   Nicotinic acid: 0.00122 g/L
#   Calcium pantothenate: 0.00122 g/L
#   Pyridoxine-HCl: 0.00122 g/L
#   Biotin: 0.00003 g/L
#   Thiamine hydrochloride: 0.00070 g/L
#   Zinc sulphate heptahydrate: 0.00814 g/L
#   Calcium chloride dihydrate: 0.01176 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00099 g/L
# Sample 28:
#   Potassium iodide: 0.00006 g/L
#   Copper (II) sulphate: 0.00008 g/L
#   Iron sulphate heptahydrate: 0.00419 g/L
#   Sodium molybdate dihydrate: 0.00056 g/L
#   Cobalt (II) chloride hexahydrate: 0.00042 g/L
#   Magnesium sulphate heptahydrate: 0.46404 g/L
#   Manganese (II) chloride dihydrate: 0.00076 g/L
#   Nicotinic acid: 0.00107 g/L
#   Calcium pantothenate: 0.00107 g/L
#   Pyridoxine-HCl: 0.00107 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00014 g/L
#   Zinc sulphate heptahydrate: 0.00130 g/L
#   Calcium chloride dihydrate: 0.00398 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00067 g/L
# Sample 29:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00293 g/L
#   Sodium molybdate dihydrate: 0.00039 g/L
#   Cobalt (II) chloride hexahydrate: 0.00029 g/L
#   Magnesium sulphate heptahydrate: 0.39066 g/L
#   Manganese (II) chloride dihydrate: 0.00064 g/L
#   Nicotinic acid: 0.00098 g/L
#   Calcium pantothenate: 0.00098 g/L
#   Pyridoxine-HCl: 0.00098 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00016 g/L
#   Zinc sulphate heptahydrate: 0.00464 g/L
#   Calcium chloride dihydrate: 0.13636 g/L
#   Inositol: 0.01318 g/L
#   para-aminobenzoic acid: 0.00009 g/L
#   Boric acid: 0.00120 g/L
# Sample 30:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00461 g/L
#   Sodium molybdate dihydrate: 0.00062 g/L
#   Cobalt (II) chloride hexahydrate: 0.00046 g/L
#   Magnesium sulphate heptahydrate: 0.33065 g/L
#   Manganese (II) chloride dihydrate: 0.00054 g/L
#   Nicotinic acid: 0.00096 g/L
#   Calcium pantothenate: 0.00096 g/L
#   Pyridoxine-HCl: 0.00096 g/L
#   Biotin: 0.00007 g/L
#   Thiamine hydrochloride: 0.00146 g/L
#   Zinc sulphate heptahydrate: 0.01276 g/L
#   Calcium chloride dihydrate: 0.00386 g/L
#   Inositol: 0.00129 g/L
#   para-aminobenzoic acid: 0.00013 g/L
#   Boric acid: 0.00215 g/L
# Sample 31:
#   Potassium iodide: 0.00011 g/L
#   Copper (II) sulphate: 0.00014 g/L
#   Iron sulphate heptahydrate: 0.00520 g/L
#   Sodium molybdate dihydrate: 0.00069 g/L
#   Cobalt (II) chloride hexahydrate: 0.00052 g/L
#   Magnesium sulphate heptahydrate: 0.46930 g/L
#   Manganese (II) chloride dihydrate: 0.00077 g/L
#   Nicotinic acid: 0.00094 g/L
#   Calcium pantothenate: 0.00094 g/L
#   Pyridoxine-HCl: 0.00094 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00021 g/L
#   Zinc sulphate heptahydrate: 0.00273 g/L
#   Calcium chloride dihydrate: 0.04913 g/L
#   Inositol: 0.01420 g/L
#   para-aminobenzoic acid: 0.00013 g/L
#   Boric acid: 0.00149 g/L
# Sample 32:
#   Potassium iodide: 0.00008 g/L
#   Copper (II) sulphate: 0.00010 g/L
#   Iron sulphate heptahydrate: 0.00747 g/L
#   Sodium molybdate dihydrate: 0.00100 g/L
#   Cobalt (II) chloride hexahydrate: 0.00075 g/L
#   Magnesium sulphate heptahydrate: 0.45861 g/L
#   Manganese (II) chloride dihydrate: 0.00075 g/L
#   Nicotinic acid: 0.00092 g/L
#   Calcium pantothenate: 0.00092 g/L
#   Pyridoxine-HCl: 0.00092 g/L
#   Biotin: 0.00005 g/L
#   Thiamine hydrochloride: 0.00097 g/L
#   Zinc sulphate heptahydrate: 0.00105 g/L
#   Calcium chloride dihydrate: 0.13133 g/L
#   Inositol: 0.00335 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00047 g/L
# Sample 33:
#   Potassium iodide: 0.00010 g/L
#   Copper (II) sulphate: 0.00013 g/L
#   Iron sulphate heptahydrate: 0.00274 g/L
#   Sodium molybdate dihydrate: 0.00037 g/L
#   Cobalt (II) chloride hexahydrate: 0.00027 g/L
#   Magnesium sulphate heptahydrate: 0.72831 g/L
#   Manganese (II) chloride dihydrate: 0.00119 g/L
#   Nicotinic acid: 0.00090 g/L
#   Calcium pantothenate: 0.00090 g/L
#   Pyridoxine-HCl: 0.00090 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00012 g/L
#   Zinc sulphate heptahydrate: 0.00231 g/L
#   Calcium chloride dihydrate: 0.12852 g/L
#   Inositol: 0.00662 g/L
#   para-aminobenzoic acid: 0.00018 g/L
#   Boric acid: 0.00168 g/L
# Sample 34:
#   Potassium iodide: 0.00016 g/L
#   Copper (II) sulphate: 0.00020 g/L
#   Iron sulphate heptahydrate: 0.00380 g/L
#   Sodium molybdate dihydrate: 0.00051 g/L
#   Cobalt (II) chloride hexahydrate: 0.00038 g/L
#   Magnesium sulphate heptahydrate: 1.03351 g/L
#   Manganese (II) chloride dihydrate: 0.00169 g/L
#   Nicotinic acid: 0.00046 g/L
#   Calcium pantothenate: 0.00046 g/L
#   Pyridoxine-HCl: 0.00046 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00021 g/L
#   Zinc sulphate heptahydrate: 0.00101 g/L
#   Calcium chloride dihydrate: 0.01392 g/L
#   Inositol: 0.00005 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00081 g/L
# Sample 35:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00427 g/L
#   Sodium molybdate dihydrate: 0.00057 g/L
#   Cobalt (II) chloride hexahydrate: 0.00043 g/L
#   Magnesium sulphate heptahydrate: 0.71578 g/L
#   Manganese (II) chloride dihydrate: 0.00117 g/L
#   Nicotinic acid: 0.00066 g/L
#   Calcium pantothenate: 0.00066 g/L
#   Pyridoxine-HCl: 0.00066 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00013 g/L
#   Zinc sulphate heptahydrate: 0.00246 g/L
#   Calcium chloride dihydrate: 0.11460 g/L
#   Inositol: 0.00113 g/L
#   para-aminobenzoic acid: 0.00010 g/L
#   Boric acid: 0.00140 g/L
# Sample 36:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.01128 g/L
#   Sodium molybdate dihydrate: 0.00150 g/L
#   Cobalt (II) chloride hexahydrate: 0.00113 g/L
#   Magnesium sulphate heptahydrate: 0.78738 g/L
#   Manganese (II) chloride dihydrate: 0.00129 g/L
#   Nicotinic acid: 0.00046 g/L
#   Calcium pantothenate: 0.00046 g/L
#   Pyridoxine-HCl: 0.00046 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00039 g/L
#   Zinc sulphate heptahydrate: 0.00051 g/L
#   Calcium chloride dihydrate: 0.03863 g/L
#   Inositol: 0.00002 g/L
#   para-aminobenzoic acid: 0.00006 g/L
#   Boric acid: 0.00054 g/L
# Sample 37:
#   Potassium iodide: 0.00006 g/L
#   Copper (II) sulphate: 0.00008 g/L
#   Iron sulphate heptahydrate: 0.00695 g/L
#   Sodium molybdate dihydrate: 0.00093 g/L
#   Cobalt (II) chloride hexahydrate: 0.00069 g/L
#   Magnesium sulphate heptahydrate: 0.35758 g/L
#   Manganese (II) chloride dihydrate: 0.00059 g/L
#   Nicotinic acid: 0.00051 g/L
#   Calcium pantothenate: 0.00051 g/L
#   Pyridoxine-HCl: 0.00051 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00018 g/L
#   Zinc sulphate heptahydrate: 0.00485 g/L
#   Calcium chloride dihydrate: 0.10407 g/L
#   Inositol: 0.00012 g/L
#   para-aminobenzoic acid: 0.00006 g/L
#   Boric acid: 0.00069 g/L
# Sample 38:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00674 g/L
#   Sodium molybdate dihydrate: 0.00090 g/L
#   Cobalt (II) chloride hexahydrate: 0.00067 g/L
#   Magnesium sulphate heptahydrate: 0.76669 g/L
#   Manganese (II) chloride dihydrate: 0.00126 g/L
#   Nicotinic acid: 0.00099 g/L
#   Calcium pantothenate: 0.00099 g/L
#   Pyridoxine-HCl: 0.00099 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00032 g/L
#   Zinc sulphate heptahydrate: 0.01055 g/L
#   Calcium chloride dihydrate: 0.01488 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00008 g/L
#   Boric acid: 0.00110 g/L
# Sample 39:
#   Potassium iodide: 0.00005 g/L
#   Copper (II) sulphate: 0.00006 g/L
#   Iron sulphate heptahydrate: 0.00382 g/L
#   Sodium molybdate dihydrate: 0.00051 g/L
#   Cobalt (II) chloride hexahydrate: 0.00038 g/L
#   Magnesium sulphate heptahydrate: 0.22512 g/L
#   Manganese (II) chloride dihydrate: 0.00037 g/L
#   Nicotinic acid: 0.00052 g/L
#   Calcium pantothenate: 0.00052 g/L
#   Pyridoxine-HCl: 0.00052 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00029 g/L
#   Zinc sulphate heptahydrate: 0.00099 g/L
#   Calcium chloride dihydrate: 0.00433 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00011 g/L
#   Boric acid: 0.00068 g/L
# Sample 40:
#   Potassium iodide: 0.00005 g/L
#   Copper (II) sulphate: 0.00006 g/L
#   Iron sulphate heptahydrate: 0.00614 g/L
#   Sodium molybdate dihydrate: 0.00082 g/L
#   Cobalt (II) chloride hexahydrate: 0.00061 g/L
#   Magnesium sulphate heptahydrate: 0.24384 g/L
#   Manganese (II) chloride dihydrate: 0.00040 g/L
#   Nicotinic acid: 0.00149 g/L
#   Calcium pantothenate: 0.00149 g/L
#   Pyridoxine-HCl: 0.00149 g/L
#   Biotin: 0.00005 g/L
#   Thiamine hydrochloride: 0.00094 g/L
#   Zinc sulphate heptahydrate: 0.01034 g/L
#   Calcium chloride dihydrate: 0.00621 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00056 g/L
# Sample 41:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00005 g/L
#   Iron sulphate heptahydrate: 0.00596 g/L
#   Sodium molybdate dihydrate: 0.00079 g/L
#   Cobalt (II) chloride hexahydrate: 0.00060 g/L
#   Magnesium sulphate heptahydrate: 0.94542 g/L
#   Manganese (II) chloride dihydrate: 0.00155 g/L
#   Nicotinic acid: 0.00056 g/L
#   Calcium pantothenate: 0.00056 g/L
#   Pyridoxine-HCl: 0.00056 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00022 g/L
#   Zinc sulphate heptahydrate: 0.00059 g/L
#   Calcium chloride dihydrate: 0.06061 g/L
#   Inositol: 0.00003 g/L
#   para-aminobenzoic acid: 0.00022 g/L
#   Boric acid: 0.00080 g/L
# Sample 42:
#   Potassium iodide: 0.00008 g/L
#   Copper (II) sulphate: 0.00010 g/L
#   Iron sulphate heptahydrate: 0.00889 g/L
#   Sodium molybdate dihydrate: 0.00118 g/L
#   Cobalt (II) chloride hexahydrate: 0.00089 g/L
#   Magnesium sulphate heptahydrate: 0.26747 g/L
#   Manganese (II) chloride dihydrate: 0.00044 g/L
#   Nicotinic acid: 0.00056 g/L
#   Calcium pantothenate: 0.00056 g/L
#   Pyridoxine-HCl: 0.00056 g/L
#   Biotin: 0.00006 g/L
#   Thiamine hydrochloride: 0.00114 g/L
#   Zinc sulphate heptahydrate: 0.00037 g/L
#   Calcium chloride dihydrate: 0.00571 g/L
#   Inositol: 0.00245 g/L
#   para-aminobenzoic acid: 0.00008 g/L
#   Boric acid: 0.00154 g/L
# Sample 43:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00917 g/L
#   Sodium molybdate dihydrate: 0.00122 g/L
#   Cobalt (II) chloride hexahydrate: 0.00092 g/L
#   Magnesium sulphate heptahydrate: 0.39268 g/L
#   Manganese (II) chloride dihydrate: 0.00064 g/L
#   Nicotinic acid: 0.00079 g/L
#   Calcium pantothenate: 0.00079 g/L
#   Pyridoxine-HCl: 0.00079 g/L
#   Biotin: 0.00005 g/L
#   Thiamine hydrochloride: 0.00095 g/L
#   Zinc sulphate heptahydrate: 0.00287 g/L
#   Calcium chloride dihydrate: 0.00976 g/L
#   Inositol: 0.00013 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00102 g/L
# Sample 44:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00005 g/L
#   Iron sulphate heptahydrate: 0.00332 g/L
#   Sodium molybdate dihydrate: 0.00044 g/L
#   Cobalt (II) chloride hexahydrate: 0.00033 g/L
#   Magnesium sulphate heptahydrate: 0.45076 g/L
#   Manganese (II) chloride dihydrate: 0.00074 g/L
#   Nicotinic acid: 0.00075 g/L
#   Calcium pantothenate: 0.00075 g/L
#   Pyridoxine-HCl: 0.00075 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00029 g/L
#   Zinc sulphate heptahydrate: 0.00113 g/L
#   Calcium chloride dihydrate: 0.05942 g/L
#   Inositol: 0.00002 g/L
#   para-aminobenzoic acid: 0.00014 g/L
#   Boric acid: 0.00174 g/L
# Sample 45:
#   Potassium iodide: 0.00020 g/L
#   Copper (II) sulphate: 0.00026 g/L
#   Iron sulphate heptahydrate: 0.00370 g/L
#   Sodium molybdate dihydrate: 0.00049 g/L
#   Cobalt (II) chloride hexahydrate: 0.00037 g/L
#   Magnesium sulphate heptahydrate: 0.48846 g/L
#   Manganese (II) chloride dihydrate: 0.00080 g/L
#   Nicotinic acid: 0.00108 g/L
#   Calcium pantothenate: 0.00108 g/L
#   Pyridoxine-HCl: 0.00108 g/L
#   Biotin: 0.00004 g/L
#   Thiamine hydrochloride: 0.00086 g/L
#   Zinc sulphate heptahydrate: 0.00398 g/L
#   Calcium chloride dihydrate: 0.03354 g/L
#   Inositol: 0.00002 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00160 g/L
# Sample 46:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00006 g/L
#   Iron sulphate heptahydrate: 0.01092 g/L
#   Sodium molybdate dihydrate: 0.00146 g/L
#   Cobalt (II) chloride hexahydrate: 0.00109 g/L
#   Magnesium sulphate heptahydrate: 0.61990 g/L
#   Manganese (II) chloride dihydrate: 0.00102 g/L
#   Nicotinic acid: 0.00078 g/L
#   Calcium pantothenate: 0.00078 g/L
#   Pyridoxine-HCl: 0.00078 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00011 g/L
#   Zinc sulphate heptahydrate: 0.00645 g/L
#   Calcium chloride dihydrate: 0.00638 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00132 g/L
# Sample 47:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.01079 g/L
#   Sodium molybdate dihydrate: 0.00144 g/L
#   Cobalt (II) chloride hexahydrate: 0.00108 g/L
#   Magnesium sulphate heptahydrate: 0.57801 g/L
#   Manganese (II) chloride dihydrate: 0.00095 g/L
#   Nicotinic acid: 0.00146 g/L
#   Calcium pantothenate: 0.00146 g/L
#   Pyridoxine-HCl: 0.00146 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00017 g/L
#   Zinc sulphate heptahydrate: 0.00163 g/L
#   Calcium chloride dihydrate: 0.00684 g/L
#   Inositol: 0.01250 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00118 g/L
# Sample 48:
#   Potassium iodide: 0.00008 g/L
#   Copper (II) sulphate: 0.00010 g/L
#   Iron sulphate heptahydrate: 0.00794 g/L
#   Sodium molybdate dihydrate: 0.00106 g/L
#   Cobalt (II) chloride hexahydrate: 0.00079 g/L
#   Magnesium sulphate heptahydrate: 0.30665 g/L
#   Manganese (II) chloride dihydrate: 0.00050 g/L
#   Nicotinic acid: 0.00157 g/L
#   Calcium pantothenate: 0.00157 g/L
#   Pyridoxine-HCl: 0.00157 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00028 g/L
#   Zinc sulphate heptahydrate: 0.00084 g/L
#   Calcium chloride dihydrate: 0.00720 g/L
#   Inositol: 0.01566 g/L
#   para-aminobenzoic acid: 0.00020 g/L
#   Boric acid: 0.00050 g/L
# Sample 49:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00338 g/L
#   Sodium molybdate dihydrate: 0.00045 g/L
#   Cobalt (II) chloride hexahydrate: 0.00034 g/L
#   Magnesium sulphate heptahydrate: 0.70655 g/L
#   Manganese (II) chloride dihydrate: 0.00116 g/L
#   Nicotinic acid: 0.00096 g/L
#   Calcium pantothenate: 0.00096 g/L
#   Pyridoxine-HCl: 0.00096 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00010 g/L
#   Zinc sulphate heptahydrate: 0.01576 g/L
#   Calcium chloride dihydrate: 0.02887 g/L
#   Inositol: 0.00264 g/L
#   para-aminobenzoic acid: 0.00007 g/L
#   Boric acid: 0.00213 g/L
# Sample 50:
#   Potassium iodide: 0.00006 g/L
#   Copper (II) sulphate: 0.00007 g/L
#   Iron sulphate heptahydrate: 0.00765 g/L
#   Sodium molybdate dihydrate: 0.00102 g/L
#   Cobalt (II) chloride hexahydrate: 0.00076 g/L
#   Magnesium sulphate heptahydrate: 0.66332 g/L
#   Manganese (II) chloride dihydrate: 0.00109 g/L
#   Nicotinic acid: 0.00095 g/L
#   Calcium pantothenate: 0.00095 g/L
#   Pyridoxine-HCl: 0.00095 g/L
#   Biotin: 0.00005 g/L
#   Thiamine hydrochloride: 0.00104 g/L
#   Zinc sulphate heptahydrate: 0.00206 g/L
#   Calcium chloride dihydrate: 0.01036 g/L
#   Inositol: 0.00094 g/L
#   para-aminobenzoic acid: 0.00012 g/L
#   Boric acid: 0.00190 g/L
# Sample 51:
#   Potassium iodide: 0.00007 g/L
#   Copper (II) sulphate: 0.00009 g/L
#   Iron sulphate heptahydrate: 0.00306 g/L
#   Sodium molybdate dihydrate: 0.00041 g/L
#   Cobalt (II) chloride hexahydrate: 0.00031 g/L
#   Magnesium sulphate heptahydrate: 0.28606 g/L
#   Manganese (II) chloride dihydrate: 0.00047 g/L
#   Nicotinic acid: 0.00061 g/L
#   Calcium pantothenate: 0.00061 g/L
#   Pyridoxine-HCl: 0.00061 g/L
#   Biotin: 0.00004 g/L
#   Thiamine hydrochloride: 0.00072 g/L
#   Zinc sulphate heptahydrate: 0.00055 g/L
#   Calcium chloride dihydrate: 0.03511 g/L
#   Inositol: 0.00309 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00051 g/L
# Sample 52:
#   Potassium iodide: 0.00010 g/L
#   Copper (II) sulphate: 0.00012 g/L
#   Iron sulphate heptahydrate: 0.00311 g/L
#   Sodium molybdate dihydrate: 0.00042 g/L
#   Cobalt (II) chloride hexahydrate: 0.00031 g/L
#   Magnesium sulphate heptahydrate: 0.68589 g/L
#   Manganese (II) chloride dihydrate: 0.00112 g/L
#   Nicotinic acid: 0.00090 g/L
#   Calcium pantothenate: 0.00090 g/L
#   Pyridoxine-HCl: 0.00090 g/L
#   Biotin: 0.00007 g/L
#   Thiamine hydrochloride: 0.00136 g/L
#   Zinc sulphate heptahydrate: 0.01155 g/L
#   Calcium chloride dihydrate: 0.01298 g/L
#   Inositol: 0.00044 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00091 g/L
# Sample 53:
#   Potassium iodide: 0.00007 g/L
#   Copper (II) sulphate: 0.00009 g/L
#   Iron sulphate heptahydrate: 0.00422 g/L
#   Sodium molybdate dihydrate: 0.00056 g/L
#   Cobalt (II) chloride hexahydrate: 0.00042 g/L
#   Magnesium sulphate heptahydrate: 1.02390 g/L
#   Manganese (II) chloride dihydrate: 0.00168 g/L
#   Nicotinic acid: 0.00084 g/L
#   Calcium pantothenate: 0.00084 g/L
#   Pyridoxine-HCl: 0.00084 g/L
#   Biotin: 0.00004 g/L
#   Thiamine hydrochloride: 0.00078 g/L
#   Zinc sulphate heptahydrate: 0.00038 g/L
#   Calcium chloride dihydrate: 0.00362 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00182 g/L
# Sample 54:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00006 g/L
#   Iron sulphate heptahydrate: 0.00640 g/L
#   Sodium molybdate dihydrate: 0.00085 g/L
#   Cobalt (II) chloride hexahydrate: 0.00064 g/L
#   Magnesium sulphate heptahydrate: 0.63350 g/L
#   Manganese (II) chloride dihydrate: 0.00104 g/L
#   Nicotinic acid: 0.00048 g/L
#   Calcium pantothenate: 0.00048 g/L
#   Pyridoxine-HCl: 0.00048 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00037 g/L
#   Zinc sulphate heptahydrate: 0.00247 g/L
#   Calcium chloride dihydrate: 0.09763 g/L
#   Inositol: 0.00210 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00196 g/L
# Sample 55:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00736 g/L
#   Sodium molybdate dihydrate: 0.00098 g/L
#   Cobalt (II) chloride hexahydrate: 0.00074 g/L
#   Magnesium sulphate heptahydrate: 0.37938 g/L
#   Manganese (II) chloride dihydrate: 0.00062 g/L
#   Nicotinic acid: 0.00084 g/L
#   Calcium pantothenate: 0.00084 g/L
#   Pyridoxine-HCl: 0.00084 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00017 g/L
#   Zinc sulphate heptahydrate: 0.01075 g/L
#   Calcium chloride dihydrate: 0.06249 g/L
#   Inositol: 0.00018 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00090 g/L
# Sample 56:
#   Potassium iodide: 0.00019 g/L
#   Copper (II) sulphate: 0.00024 g/L
#   Iron sulphate heptahydrate: 0.00473 g/L
#   Sodium molybdate dihydrate: 0.00063 g/L
#   Cobalt (II) chloride hexahydrate: 0.00047 g/L
#   Magnesium sulphate heptahydrate: 0.37817 g/L
#   Manganese (II) chloride dihydrate: 0.00062 g/L
#   Nicotinic acid: 0.00160 g/L
#   Calcium pantothenate: 0.00160 g/L
#   Pyridoxine-HCl: 0.00160 g/L
#   Biotin: 0.00006 g/L
#   Thiamine hydrochloride: 0.00116 g/L
#   Zinc sulphate heptahydrate: 0.00533 g/L
#   Calcium chloride dihydrate: 0.00705 g/L
#   Inositol: 0.01009 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00175 g/L
# Sample 57:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00673 g/L
#   Sodium molybdate dihydrate: 0.00090 g/L
#   Cobalt (II) chloride hexahydrate: 0.00067 g/L
#   Magnesium sulphate heptahydrate: 0.22910 g/L
#   Manganese (II) chloride dihydrate: 0.00038 g/L
#   Nicotinic acid: 0.00130 g/L
#   Calcium pantothenate: 0.00130 g/L
#   Pyridoxine-HCl: 0.00130 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00018 g/L
#   Zinc sulphate heptahydrate: 0.00160 g/L
#   Calcium chloride dihydrate: 0.09314 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00006 g/L
#   Boric acid: 0.00071 g/L
# Sample 58:
#   Potassium iodide: 0.00012 g/L
#   Copper (II) sulphate: 0.00015 g/L
#   Iron sulphate heptahydrate: 0.00397 g/L
#   Sodium molybdate dihydrate: 0.00053 g/L
#   Cobalt (II) chloride hexahydrate: 0.00040 g/L
#   Magnesium sulphate heptahydrate: 0.25110 g/L
#   Manganese (II) chloride dihydrate: 0.00041 g/L
#   Nicotinic acid: 0.00054 g/L
#   Calcium pantothenate: 0.00054 g/L
#   Pyridoxine-HCl: 0.00054 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00025 g/L
#   Zinc sulphate heptahydrate: 0.00042 g/L
#   Calcium chloride dihydrate: 0.05098 g/L
#   Inositol: 0.00800 g/L
#   para-aminobenzoic acid: 0.00008 g/L
#   Boric acid: 0.00095 g/L
# Sample 59:
#   Potassium iodide: 0.00007 g/L
#   Copper (II) sulphate: 0.00009 g/L
#   Iron sulphate heptahydrate: 0.00432 g/L
#   Sodium molybdate dihydrate: 0.00058 g/L
#   Cobalt (II) chloride hexahydrate: 0.00043 g/L
#   Magnesium sulphate heptahydrate: 0.62935 g/L
#   Manganese (II) chloride dihydrate: 0.00103 g/L
#   Nicotinic acid: 0.00158 g/L
#   Calcium pantothenate: 0.00158 g/L
#   Pyridoxine-HCl: 0.00158 g/L
#   Biotin: 0.00003 g/L
#   Thiamine hydrochloride: 0.00063 g/L
#   Zinc sulphate heptahydrate: 0.00121 g/L
#   Calcium chloride dihydrate: 0.00975 g/L
#   Inositol: 0.01822 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00117 g/L
# Sample 60:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00454 g/L
#   Sodium molybdate dihydrate: 0.00060 g/L
#   Cobalt (II) chloride hexahydrate: 0.00045 g/L
#   Magnesium sulphate heptahydrate: 0.61647 g/L
#   Manganese (II) chloride dihydrate: 0.00101 g/L
#   Nicotinic acid: 0.00103 g/L
#   Calcium pantothenate: 0.00103 g/L
#   Pyridoxine-HCl: 0.00103 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00013 g/L
#   Zinc sulphate heptahydrate: 0.00376 g/L
#   Calcium chloride dihydrate: 0.04536 g/L
#   Inositol: 0.00495 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00101 g/L
# Sample 61:
#   Potassium iodide: 0.00015 g/L
#   Copper (II) sulphate: 0.00019 g/L
#   Iron sulphate heptahydrate: 0.00283 g/L
#   Sodium molybdate dihydrate: 0.00038 g/L
#   Cobalt (II) chloride hexahydrate: 0.00028 g/L
#   Magnesium sulphate heptahydrate: 0.95235 g/L
#   Manganese (II) chloride dihydrate: 0.00156 g/L
#   Nicotinic acid: 0.00118 g/L
#   Calcium pantothenate: 0.00118 g/L
#   Pyridoxine-HCl: 0.00118 g/L
#   Biotin: 0.00006 g/L
#   Thiamine hydrochloride: 0.00128 g/L
#   Zinc sulphate heptahydrate: 0.01134 g/L
#   Calcium chloride dihydrate: 0.01560 g/L
#   Inositol: 0.00184 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00066 g/L
# Sample 62:
#   Potassium iodide: 0.00021 g/L
#   Copper (II) sulphate: 0.00027 g/L
#   Iron sulphate heptahydrate: 0.00278 g/L
#   Sodium molybdate dihydrate: 0.00037 g/L
#   Cobalt (II) chloride hexahydrate: 0.00028 g/L
#   Magnesium sulphate heptahydrate: 0.73989 g/L
#   Manganese (II) chloride dihydrate: 0.00121 g/L
#   Nicotinic acid: 0.00087 g/L
#   Calcium pantothenate: 0.00087 g/L
#   Pyridoxine-HCl: 0.00087 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00011 g/L
#   Zinc sulphate heptahydrate: 0.00066 g/L
#   Calcium chloride dihydrate: 0.04305 g/L
#   Inositol: 0.00019 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00098 g/L
# Sample 63:
#   Potassium iodide: 0.00021 g/L
#   Copper (II) sulphate: 0.00026 g/L
#   Iron sulphate heptahydrate: 0.01271 g/L
#   Sodium molybdate dihydrate: 0.00170 g/L
#   Cobalt (II) chloride hexahydrate: 0.00127 g/L
#   Magnesium sulphate heptahydrate: 0.35420 g/L
#   Manganese (II) chloride dihydrate: 0.00058 g/L
#   Nicotinic acid: 0.00063 g/L
#   Calcium pantothenate: 0.00063 g/L
#   Pyridoxine-HCl: 0.00063 g/L
#   Biotin: 0.00008 g/L
#   Thiamine hydrochloride: 0.00162 g/L
#   Zinc sulphate heptahydrate: 0.00132 g/L
#   Calcium chloride dihydrate: 0.01261 g/L
#   Inositol: 0.01059 g/L
#   para-aminobenzoic acid: 0.00017 g/L
#   Boric acid: 0.00070 g/L
# Sample 64:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00005 g/L
#   Iron sulphate heptahydrate: 0.00415 g/L
#   Sodium molybdate dihydrate: 0.00055 g/L
#   Cobalt (II) chloride hexahydrate: 0.00041 g/L
#   Magnesium sulphate heptahydrate: 0.97138 g/L
#   Manganese (II) chloride dihydrate: 0.00159 g/L
#   Nicotinic acid: 0.00132 g/L
#   Calcium pantothenate: 0.00132 g/L
#   Pyridoxine-HCl: 0.00132 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00030 g/L
#   Zinc sulphate heptahydrate: 0.00192 g/L
#   Calcium chloride dihydrate: 0.00583 g/L
#   Inositol: 0.00003 g/L
#   para-aminobenzoic acid: 0.00013 g/L
#   Boric acid: 0.00054 g/L
# Sample 65:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00529 g/L
#   Sodium molybdate dihydrate: 0.00071 g/L
#   Cobalt (II) chloride hexahydrate: 0.00053 g/L
#   Magnesium sulphate heptahydrate: 0.50187 g/L
#   Manganese (II) chloride dihydrate: 0.00082 g/L
#   Nicotinic acid: 0.00137 g/L
#   Calcium pantothenate: 0.00137 g/L
#   Pyridoxine-HCl: 0.00137 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00017 g/L
#   Zinc sulphate heptahydrate: 0.00148 g/L
#   Calcium chloride dihydrate: 0.03566 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00010 g/L
#   Boric acid: 0.00116 g/L
# Sample 66:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00005 g/L
#   Iron sulphate heptahydrate: 0.00447 g/L
#   Sodium molybdate dihydrate: 0.00060 g/L
#   Cobalt (II) chloride hexahydrate: 0.00045 g/L
#   Magnesium sulphate heptahydrate: 1.05559 g/L
#   Manganese (II) chloride dihydrate: 0.00173 g/L
#   Nicotinic acid: 0.00155 g/L
#   Calcium pantothenate: 0.00155 g/L
#   Pyridoxine-HCl: 0.00155 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00021 g/L
#   Zinc sulphate heptahydrate: 0.00182 g/L
#   Calcium chloride dihydrate: 0.04449 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00011 g/L
#   Boric acid: 0.00092 g/L
# Sample 67:
#   Potassium iodide: 0.00010 g/L
#   Copper (II) sulphate: 0.00013 g/L
#   Iron sulphate heptahydrate: 0.00589 g/L
#   Sodium molybdate dihydrate: 0.00078 g/L
#   Cobalt (II) chloride hexahydrate: 0.00059 g/L
#   Magnesium sulphate heptahydrate: 0.67991 g/L
#   Manganese (II) chloride dihydrate: 0.00112 g/L
#   Nicotinic acid: 0.00073 g/L
#   Calcium pantothenate: 0.00073 g/L
#   Pyridoxine-HCl: 0.00073 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00044 g/L
#   Zinc sulphate heptahydrate: 0.01301 g/L
#   Calcium chloride dihydrate: 0.01132 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00006 g/L
#   Boric acid: 0.00057 g/L
# Sample 68:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00002 g/L
#   Iron sulphate heptahydrate: 0.01174 g/L
#   Sodium molybdate dihydrate: 0.00157 g/L
#   Cobalt (II) chloride hexahydrate: 0.00117 g/L
#   Magnesium sulphate heptahydrate: 0.80189 g/L
#   Manganese (II) chloride dihydrate: 0.00132 g/L
#   Nicotinic acid: 0.00138 g/L
#   Calcium pantothenate: 0.00138 g/L
#   Pyridoxine-HCl: 0.00138 g/L
#   Biotin: 0.00005 g/L
#   Thiamine hydrochloride: 0.00098 g/L
#   Zinc sulphate heptahydrate: 0.00111 g/L
#   Calcium chloride dihydrate: 0.02537 g/L
#   Inositol: 0.00004 g/L
#   para-aminobenzoic acid: 0.00011 g/L
#   Boric acid: 0.00072 g/L
# Sample 69:
#   Potassium iodide: 0.00005 g/L
#   Copper (II) sulphate: 0.00006 g/L
#   Iron sulphate heptahydrate: 0.01147 g/L
#   Sodium molybdate dihydrate: 0.00153 g/L
#   Cobalt (II) chloride hexahydrate: 0.00115 g/L
#   Magnesium sulphate heptahydrate: 0.65476 g/L
#   Manganese (II) chloride dihydrate: 0.00107 g/L
#   Nicotinic acid: 0.00060 g/L
#   Calcium pantothenate: 0.00060 g/L
#   Pyridoxine-HCl: 0.00060 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00034 g/L
#   Zinc sulphate heptahydrate: 0.00513 g/L
#   Calcium chloride dihydrate: 0.05649 g/L
#   Inositol: 0.00026 g/L
#   para-aminobenzoic acid: 0.00016 g/L
#   Boric acid: 0.00046 g/L
# Sample 70:
#   Potassium iodide: 0.00006 g/L
#   Copper (II) sulphate: 0.00007 g/L
#   Iron sulphate heptahydrate: 0.01158 g/L
#   Sodium molybdate dihydrate: 0.00154 g/L
#   Cobalt (II) chloride hexahydrate: 0.00116 g/L
#   Magnesium sulphate heptahydrate: 0.66988 g/L
#   Manganese (II) chloride dihydrate: 0.00110 g/L
#   Nicotinic acid: 0.00119 g/L
#   Calcium pantothenate: 0.00119 g/L
#   Pyridoxine-HCl: 0.00119 g/L
#   Biotin: 0.00007 g/L
#   Thiamine hydrochloride: 0.00147 g/L
#   Zinc sulphate heptahydrate: 0.00924 g/L
#   Calcium chloride dihydrate: 0.01380 g/L
#   Inositol: 0.00052 g/L
#   para-aminobenzoic acid: 0.00014 g/L
#   Boric acid: 0.00112 g/L
# Sample 71:
#   Potassium iodide: 0.00007 g/L
#   Copper (II) sulphate: 0.00009 g/L
#   Iron sulphate heptahydrate: 0.01259 g/L
#   Sodium molybdate dihydrate: 0.00168 g/L
#   Cobalt (II) chloride hexahydrate: 0.00126 g/L
#   Magnesium sulphate heptahydrate: 0.40570 g/L
#   Manganese (II) chloride dihydrate: 0.00067 g/L
#   Nicotinic acid: 0.00111 g/L
#   Calcium pantothenate: 0.00111 g/L
#   Pyridoxine-HCl: 0.00111 g/L
#   Biotin: 0.00006 g/L
#   Thiamine hydrochloride: 0.00126 g/L
#   Zinc sulphate heptahydrate: 0.00089 g/L
#   Calcium chloride dihydrate: 0.05556 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00088 g/L
# Sample 72:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00740 g/L
#   Sodium molybdate dihydrate: 0.00099 g/L
#   Cobalt (II) chloride hexahydrate: 0.00074 g/L
#   Magnesium sulphate heptahydrate: 0.36101 g/L
#   Manganese (II) chloride dihydrate: 0.00059 g/L
#   Nicotinic acid: 0.00051 g/L
#   Calcium pantothenate: 0.00051 g/L
#   Pyridoxine-HCl: 0.00051 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00047 g/L
#   Zinc sulphate heptahydrate: 0.01466 g/L
#   Calcium chloride dihydrate: 0.00554 g/L
#   Inositol: 0.00080 g/L
#   para-aminobenzoic acid: 0.00009 g/L
#   Boric acid: 0.00194 g/L
# Sample 73:
#   Potassium iodide: 0.00005 g/L
#   Copper (II) sulphate: 0.00006 g/L
#   Iron sulphate heptahydrate: 0.01218 g/L
#   Sodium molybdate dihydrate: 0.00162 g/L
#   Cobalt (II) chloride hexahydrate: 0.00122 g/L
#   Magnesium sulphate heptahydrate: 0.57151 g/L
#   Manganese (II) chloride dihydrate: 0.00094 g/L
#   Nicotinic acid: 0.00099 g/L
#   Calcium pantothenate: 0.00099 g/L
#   Pyridoxine-HCl: 0.00099 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00031 g/L
#   Zinc sulphate heptahydrate: 0.00082 g/L
#   Calcium chloride dihydrate: 0.02136 g/L
#   Inositol: 0.00005 g/L
#   para-aminobenzoic acid: 0.00009 g/L
#   Boric acid: 0.00143 g/L
# Sample 74:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00005 g/L
#   Iron sulphate heptahydrate: 0.01017 g/L
#   Sodium molybdate dihydrate: 0.00136 g/L
#   Cobalt (II) chloride hexahydrate: 0.00102 g/L
#   Magnesium sulphate heptahydrate: 0.32767 g/L
#   Manganese (II) chloride dihydrate: 0.00054 g/L
#   Nicotinic acid: 0.00048 g/L
#   Calcium pantothenate: 0.00048 g/L
#   Pyridoxine-HCl: 0.00048 g/L
#   Biotin: 0.00007 g/L
#   Thiamine hydrochloride: 0.00142 g/L
#   Zinc sulphate heptahydrate: 0.00498 g/L
#   Calcium chloride dihydrate: 0.00909 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00008 g/L
#   Boric acid: 0.00052 g/L
# Sample 75:
#   Potassium iodide: 0.00011 g/L
#   Copper (II) sulphate: 0.00014 g/L
#   Iron sulphate heptahydrate: 0.00683 g/L
#   Sodium molybdate dihydrate: 0.00091 g/L
#   Cobalt (II) chloride hexahydrate: 0.00068 g/L
#   Magnesium sulphate heptahydrate: 0.68938 g/L
#   Manganese (II) chloride dihydrate: 0.00113 g/L
#   Nicotinic acid: 0.00165 g/L
#   Calcium pantothenate: 0.00165 g/L
# ...
#   Inositol: 0.00163 g/L
#   para-aminobenzoic acid: 0.00021 g/L
#   Boric acid: 0.00143 g/L
# Sample 166:
#   Potassium iodide: 0.00013 g/L
#   Copper (II) sulphate: 0.00017 g/L
#   Iron sulphate heptahydrate: 0.00349 g/L
#   Sodium molybdate dihydrate: 0.00046 g/L
#   Cobalt (II) chloride hexahydrate: 0.00035 g/L
#   Magnesium sulphate heptahydrate: 1.01251 g/L
#   Manganese (II) chloride dihydrate: 0.00166 g/L
#   Nicotinic acid: 0.00049 g/L
#   Calcium pantothenate: 0.00049 g/L
#   Pyridoxine-HCl: 0.00049 g/L
#   Biotin: 0.00007 g/L
#   Thiamine hydrochloride: 0.00140 g/L
#   Zinc sulphate heptahydrate: 0.00142 g/L
#   Calcium chloride dihydrate: 0.06887 g/L
#   Inositol: 0.00038 g/L
#   para-aminobenzoic acid: 0.00013 g/L
#   Boric acid: 0.00140 g/L
# Sample 167:
#   Potassium iodide: 0.00006 g/L
#   Copper (II) sulphate: 0.00008 g/L
#   Iron sulphate heptahydrate: 0.01106 g/L
#   Sodium molybdate dihydrate: 0.00147 g/L
#   Cobalt (II) chloride hexahydrate: 0.00111 g/L
#   Magnesium sulphate heptahydrate: 0.46152 g/L
#   Manganese (II) chloride dihydrate: 0.00076 g/L
#   Nicotinic acid: 0.00086 g/L
#   Calcium pantothenate: 0.00086 g/L
#   Pyridoxine-HCl: 0.00086 g/L
#   Biotin: 0.00004 g/L
#   Thiamine hydrochloride: 0.00070 g/L
#   Zinc sulphate heptahydrate: 0.00184 g/L
#   Calcium chloride dihydrate: 0.00653 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00121 g/L
# Sample 168:
#   Potassium iodide: 0.00005 g/L
#   Copper (II) sulphate: 0.00006 g/L
#   Iron sulphate heptahydrate: 0.00816 g/L
#   Sodium molybdate dihydrate: 0.00109 g/L
#   Cobalt (II) chloride hexahydrate: 0.00082 g/L
#   Magnesium sulphate heptahydrate: 0.55563 g/L
#   Manganese (II) chloride dihydrate: 0.00091 g/L
#   Nicotinic acid: 0.00111 g/L
#   Calcium pantothenate: 0.00111 g/L
#   Pyridoxine-HCl: 0.00111 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00024 g/L
#   Zinc sulphate heptahydrate: 0.00073 g/L
#   Calcium chloride dihydrate: 0.00323 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00016 g/L
#   Boric acid: 0.00073 g/L
# Sample 169:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00470 g/L
#   Sodium molybdate dihydrate: 0.00063 g/L
#   Cobalt (II) chloride hexahydrate: 0.00047 g/L
#   Magnesium sulphate heptahydrate: 0.59313 g/L
#   Manganese (II) chloride dihydrate: 0.00097 g/L
#   Nicotinic acid: 0.00081 g/L
#   Calcium pantothenate: 0.00081 g/L
#   Pyridoxine-HCl: 0.00081 g/L
#   Biotin: 0.00008 g/L
#   Thiamine hydrochloride: 0.00164 g/L
#   Zinc sulphate heptahydrate: 0.00057 g/L
#   Calcium chloride dihydrate: 0.06148 g/L
#   Inositol: 0.03055 g/L
#   para-aminobenzoic acid: 0.00016 g/L
#   Boric acid: 0.00049 g/L
# Sample 170:
#   Potassium iodide: 0.00005 g/L
#   Copper (II) sulphate: 0.00007 g/L
#   Iron sulphate heptahydrate: 0.00463 g/L
#   Sodium molybdate dihydrate: 0.00062 g/L
#   Cobalt (II) chloride hexahydrate: 0.00046 g/L
#   Magnesium sulphate heptahydrate: 0.33448 g/L
#   Manganese (II) chloride dihydrate: 0.00055 g/L
#   Nicotinic acid: 0.00152 g/L
#   Calcium pantothenate: 0.00152 g/L
#   Pyridoxine-HCl: 0.00152 g/L
#   Biotin: 0.00003 g/L
#   Thiamine hydrochloride: 0.00053 g/L
#   Zinc sulphate heptahydrate: 0.01460 g/L
#   Calcium chloride dihydrate: 0.02544 g/L
#   Inositol: 0.00007 g/L
#   para-aminobenzoic acid: 0.00011 g/L
#   Boric acid: 0.00052 g/L
# Sample 171:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00005 g/L
#   Iron sulphate heptahydrate: 0.00426 g/L
#   Sodium molybdate dihydrate: 0.00057 g/L
#   Cobalt (II) chloride hexahydrate: 0.00043 g/L
#   Magnesium sulphate heptahydrate: 0.52296 g/L
#   Manganese (II) chloride dihydrate: 0.00086 g/L
#   Nicotinic acid: 0.00081 g/L
#   Calcium pantothenate: 0.00081 g/L
#   Pyridoxine-HCl: 0.00081 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00041 g/L
#   Zinc sulphate heptahydrate: 0.00068 g/L
#   Calcium chloride dihydrate: 0.01251 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00052 g/L
# Sample 172:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00006 g/L
#   Iron sulphate heptahydrate: 0.00280 g/L
#   Sodium molybdate dihydrate: 0.00037 g/L
#   Cobalt (II) chloride hexahydrate: 0.00028 g/L
#   Magnesium sulphate heptahydrate: 0.54728 g/L
#   Manganese (II) chloride dihydrate: 0.00090 g/L
#   Nicotinic acid: 0.00052 g/L
#   Calcium pantothenate: 0.00052 g/L
#   Pyridoxine-HCl: 0.00052 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00045 g/L
#   Zinc sulphate heptahydrate: 0.00253 g/L
#   Calcium chloride dihydrate: 0.00826 g/L
#   Inositol: 0.00033 g/L
#   para-aminobenzoic acid: 0.00020 g/L
#   Boric acid: 0.00046 g/L
# Sample 173:
#   Potassium iodide: 0.00011 g/L
#   Copper (II) sulphate: 0.00015 g/L
#   Iron sulphate heptahydrate: 0.01204 g/L
#   Sodium molybdate dihydrate: 0.00160 g/L
#   Cobalt (II) chloride hexahydrate: 0.00120 g/L
#   Magnesium sulphate heptahydrate: 0.23187 g/L
#   Manganese (II) chloride dihydrate: 0.00038 g/L
#   Nicotinic acid: 0.00067 g/L
#   Calcium pantothenate: 0.00067 g/L
#   Pyridoxine-HCl: 0.00067 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00036 g/L
#   Zinc sulphate heptahydrate: 0.00450 g/L
#   Calcium chloride dihydrate: 0.07011 g/L
#   Inositol: 0.00001 g/L
#   para-aminobenzoic acid: 0.00010 g/L
#   Boric acid: 0.00076 g/L
# Sample 174:
#   Potassium iodide: 0.00004 g/L
#   Copper (II) sulphate: 0.00005 g/L
#   Iron sulphate heptahydrate: 0.00335 g/L
#   Sodium molybdate dihydrate: 0.00045 g/L
#   Cobalt (II) chloride hexahydrate: 0.00034 g/L
#   Magnesium sulphate heptahydrate: 0.93114 g/L
#   Manganese (II) chloride dihydrate: 0.00153 g/L
#   Nicotinic acid: 0.00057 g/L
#   Calcium pantothenate: 0.00057 g/L
#   Pyridoxine-HCl: 0.00057 g/L
#   Biotin: 0.00004 g/L
#   Thiamine hydrochloride: 0.00079 g/L
#   Zinc sulphate heptahydrate: 0.00588 g/L
#   Calcium chloride dihydrate: 0.01778 g/L
#   Inositol: 0.00003 g/L
#   para-aminobenzoic acid: 0.00018 g/L
#   Boric acid: 0.00105 g/L
# Sample 175:
#   Potassium iodide: 0.00006 g/L
#   Copper (II) sulphate: 0.00008 g/L
#   Iron sulphate heptahydrate: 0.00342 g/L
#   Sodium molybdate dihydrate: 0.00046 g/L
#   Cobalt (II) chloride hexahydrate: 0.00034 g/L
#   Magnesium sulphate heptahydrate: 0.48276 g/L
#   Manganese (II) chloride dihydrate: 0.00079 g/L
#   Nicotinic acid: 0.00091 g/L
#   Calcium pantothenate: 0.00091 g/L
#   Pyridoxine-HCl: 0.00091 g/L
#   Biotin: 0.00003 g/L
#   Thiamine hydrochloride: 0.00059 g/L
#   Zinc sulphate heptahydrate: 0.00870 g/L
#   Calcium chloride dihydrate: 0.00275 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00008 g/L
#   Boric acid: 0.00065 g/L
# Sample 176:
#   Potassium iodide: 0.00018 g/L
#   Copper (II) sulphate: 0.00023 g/L
#   Iron sulphate heptahydrate: 0.00395 g/L
#   Sodium molybdate dihydrate: 0.00053 g/L
#   Cobalt (II) chloride hexahydrate: 0.00040 g/L
#   Magnesium sulphate heptahydrate: 0.35938 g/L
#   Manganese (II) chloride dihydrate: 0.00059 g/L
#   Nicotinic acid: 0.00150 g/L
#   Calcium pantothenate: 0.00150 g/L
#   Pyridoxine-HCl: 0.00150 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00042 g/L
#   Zinc sulphate heptahydrate: 0.00044 g/L
#   Calcium chloride dihydrate: 0.00857 g/L
#   Inositol: 0.00062 g/L
#   para-aminobenzoic acid: 0.00003 g/L
#   Boric acid: 0.00124 g/L
# Sample 177:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00327 g/L
#   Sodium molybdate dihydrate: 0.00044 g/L
#   Cobalt (II) chloride hexahydrate: 0.00033 g/L
#   Magnesium sulphate heptahydrate: 0.22210 g/L
#   Manganese (II) chloride dihydrate: 0.00036 g/L
#   Nicotinic acid: 0.00048 g/L
#   Calcium pantothenate: 0.00048 g/L
#   Pyridoxine-HCl: 0.00048 g/L
#   Biotin: 0.00005 g/L
#   Thiamine hydrochloride: 0.00091 g/L
#   Zinc sulphate heptahydrate: 0.00141 g/L
#   Calcium chloride dihydrate: 0.03775 g/L
#   Inositol: 0.00017 g/L
#   para-aminobenzoic acid: 0.00011 g/L
#   Boric acid: 0.00132 g/L
# Sample 178:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00552 g/L
#   Sodium molybdate dihydrate: 0.00074 g/L
#   Cobalt (II) chloride hexahydrate: 0.00055 g/L
#   Magnesium sulphate heptahydrate: 0.55876 g/L
#   Manganese (II) chloride dihydrate: 0.00092 g/L
#   Nicotinic acid: 0.00059 g/L
#   Calcium pantothenate: 0.00059 g/L
#   Pyridoxine-HCl: 0.00059 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00012 g/L
#   Zinc sulphate heptahydrate: 0.00052 g/L
#   Calcium chloride dihydrate: 0.02341 g/L
#   Inositol: 0.00932 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00134 g/L
# Sample 179:
#   Potassium iodide: 0.00016 g/L
#   Copper (II) sulphate: 0.00021 g/L
#   Iron sulphate heptahydrate: 0.00307 g/L
#   Sodium molybdate dihydrate: 0.00041 g/L
#   Cobalt (II) chloride hexahydrate: 0.00031 g/L
#   Magnesium sulphate heptahydrate: 0.60507 g/L
#   Manganese (II) chloride dihydrate: 0.00099 g/L
#   Nicotinic acid: 0.00063 g/L
#   Calcium pantothenate: 0.00063 g/L
#   Pyridoxine-HCl: 0.00063 g/L
#   Biotin: 0.00007 g/L
#   Thiamine hydrochloride: 0.00132 g/L
#   Zinc sulphate heptahydrate: 0.00196 g/L
#   Calcium chloride dihydrate: 0.02791 g/L
#   Inositol: 0.00002 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00176 g/L
# Sample 180:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00004 g/L
#   Iron sulphate heptahydrate: 0.00345 g/L
#   Sodium molybdate dihydrate: 0.00046 g/L
#   Cobalt (II) chloride hexahydrate: 0.00035 g/L
#   Magnesium sulphate heptahydrate: 0.56287 g/L
#   Manganese (II) chloride dihydrate: 0.00092 g/L
#   Nicotinic acid: 0.00107 g/L
#   Calcium pantothenate: 0.00107 g/L
#   Pyridoxine-HCl: 0.00107 g/L
#   Biotin: 0.00008 g/L
#   Thiamine hydrochloride: 0.00158 g/L
#   Zinc sulphate heptahydrate: 0.00429 g/L
#   Calcium chloride dihydrate: 0.00791 g/L
#   Inositol: 0.00008 g/L
#   para-aminobenzoic acid: 0.00010 g/L
#   Boric acid: 0.00085 g/L
# Sample 181:
#   Potassium iodide: 0.00018 g/L
#   Copper (II) sulphate: 0.00023 g/L
#   Iron sulphate heptahydrate: 0.01046 g/L
#   Sodium molybdate dihydrate: 0.00139 g/L
#   Cobalt (II) chloride hexahydrate: 0.00105 g/L
#   Magnesium sulphate heptahydrate: 0.26164 g/L
#   Manganese (II) chloride dihydrate: 0.00043 g/L
#   Nicotinic acid: 0.00059 g/L
#   Calcium pantothenate: 0.00059 g/L
#   Pyridoxine-HCl: 0.00059 g/L
#   Biotin: 0.00005 g/L
#   Thiamine hydrochloride: 0.00093 g/L
#   Zinc sulphate heptahydrate: 0.00136 g/L
#   Calcium chloride dihydrate: 0.05385 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00108 g/L
# Sample 182:
#   Potassium iodide: 0.00015 g/L
#   Copper (II) sulphate: 0.00019 g/L
#   Iron sulphate heptahydrate: 0.01279 g/L
#   Sodium molybdate dihydrate: 0.00171 g/L
#   Cobalt (II) chloride hexahydrate: 0.00128 g/L
#   Magnesium sulphate heptahydrate: 0.99473 g/L
#   Manganese (II) chloride dihydrate: 0.00163 g/L
#   Nicotinic acid: 0.00069 g/L
#   Calcium pantothenate: 0.00069 g/L
#   Pyridoxine-HCl: 0.00069 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00026 g/L
#   Zinc sulphate heptahydrate: 0.00343 g/L
#   Calcium chloride dihydrate: 0.11731 g/L
#   Inositol: 0.00521 g/L
#   para-aminobenzoic acid: 0.00017 g/L
#   Boric acid: 0.00130 g/L
# Sample 183:
#   Potassium iodide: 0.00012 g/L
#   Copper (II) sulphate: 0.00015 g/L
#   Iron sulphate heptahydrate: 0.00289 g/L
#   Sodium molybdate dihydrate: 0.00039 g/L
#   Cobalt (II) chloride hexahydrate: 0.00029 g/L
#   Magnesium sulphate heptahydrate: 0.52105 g/L
#   Manganese (II) chloride dihydrate: 0.00085 g/L
#   Nicotinic acid: 0.00112 g/L
#   Calcium pantothenate: 0.00112 g/L
#   Pyridoxine-HCl: 0.00112 g/L
#   Biotin: 0.00003 g/L
#   Thiamine hydrochloride: 0.00054 g/L
#   Zinc sulphate heptahydrate: 0.00318 g/L
#   Calcium chloride dihydrate: 0.00884 g/L
#   Inositol: 0.01701 g/L
#   para-aminobenzoic acid: 0.00020 g/L
#   Boric acid: 0.00086 g/L
# Sample 184:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.01182 g/L
#   Sodium molybdate dihydrate: 0.00158 g/L
#   Cobalt (II) chloride hexahydrate: 0.00118 g/L
#   Magnesium sulphate heptahydrate: 0.84202 g/L
#   Manganese (II) chloride dihydrate: 0.00138 g/L
#   Nicotinic acid: 0.00091 g/L
#   Calcium pantothenate: 0.00091 g/L
#   Pyridoxine-HCl: 0.00091 g/L
#   Biotin: 0.00002 g/L
#   Thiamine hydrochloride: 0.00036 g/L
#   Zinc sulphate heptahydrate: 0.00333 g/L
#   Calcium chloride dihydrate: 0.03979 g/L
#   Inositol: 0.00107 g/L
#   para-aminobenzoic acid: 0.00005 g/L
#   Boric acid: 0.00204 g/L
# Sample 185:
#   Potassium iodide: 0.00013 g/L
#   Copper (II) sulphate: 0.00016 g/L
#   Iron sulphate heptahydrate: 0.00317 g/L
#   Sodium molybdate dihydrate: 0.00042 g/L
#   Cobalt (II) chloride hexahydrate: 0.00032 g/L
#   Magnesium sulphate heptahydrate: 0.25514 g/L
#   Manganese (II) chloride dihydrate: 0.00042 g/L
#   Nicotinic acid: 0.00089 g/L
#   Calcium pantothenate: 0.00089 g/L
#   Pyridoxine-HCl: 0.00089 g/L
#   Biotin: 0.00006 g/L
#   Thiamine hydrochloride: 0.00123 g/L
#   Zinc sulphate heptahydrate: 0.00478 g/L
#   Calcium chloride dihydrate: 0.02165 g/L
#   Inositol: 0.00002 g/L
#   para-aminobenzoic acid: 0.00008 g/L
#   Boric acid: 0.00077 g/L
# Sample 186:
#   Potassium iodide: 0.00014 g/L
#   Copper (II) sulphate: 0.00018 g/L
#   Iron sulphate heptahydrate: 0.00807 g/L
#   Sodium molybdate dihydrate: 0.00108 g/L
#   Cobalt (II) chloride hexahydrate: 0.00081 g/L
#   Magnesium sulphate heptahydrate: 0.25351 g/L
#   Manganese (II) chloride dihydrate: 0.00042 g/L
#   Nicotinic acid: 0.00117 g/L
#   Calcium pantothenate: 0.00117 g/L
#   Pyridoxine-HCl: 0.00117 g/L
#   Biotin: 0.00006 g/L
#   Thiamine hydrochloride: 0.00112 g/L
#   Zinc sulphate heptahydrate: 0.00329 g/L
#   Calcium chloride dihydrate: 0.09441 g/L
#   Inositol: 0.00013 g/L
#   para-aminobenzoic acid: 0.00007 g/L
#   Boric acid: 0.00064 g/L
# Sample 187:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00361 g/L
#   Sodium molybdate dihydrate: 0.00048 g/L
#   Cobalt (II) chloride hexahydrate: 0.00036 g/L
#   Magnesium sulphate heptahydrate: 0.22978 g/L
#   Manganese (II) chloride dihydrate: 0.00038 g/L
#   Nicotinic acid: 0.00116 g/L
#   Calcium pantothenate: 0.00116 g/L
#   Pyridoxine-HCl: 0.00116 g/L
#   Biotin: 0.00005 g/L
#   Thiamine hydrochloride: 0.00099 g/L
#   Zinc sulphate heptahydrate: 0.00598 g/L
#   Calcium chloride dihydrate: 0.10481 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00016 g/L
#   Boric acid: 0.00088 g/L
# Sample 188:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00002 g/L
#   Iron sulphate heptahydrate: 0.00661 g/L
#   Sodium molybdate dihydrate: 0.00088 g/L
#   Cobalt (II) chloride hexahydrate: 0.00066 g/L
#   Magnesium sulphate heptahydrate: 1.04986 g/L
#   Manganese (II) chloride dihydrate: 0.00172 g/L
#   Nicotinic acid: 0.00068 g/L
#   Calcium pantothenate: 0.00068 g/L
#   Pyridoxine-HCl: 0.00068 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00017 g/L
#   Zinc sulphate heptahydrate: 0.00073 g/L
#   Calcium chloride dihydrate: 0.04154 g/L
#   Inositol: 0.00005 g/L
#   para-aminobenzoic acid: 0.00004 g/L
#   Boric acid: 0.00187 g/L
# Sample 189:
#   Potassium iodide: 0.00002 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00295 g/L
#   Sodium molybdate dihydrate: 0.00039 g/L
#   Cobalt (II) chloride hexahydrate: 0.00030 g/L
#   Magnesium sulphate heptahydrate: 0.49561 g/L
#   Manganese (II) chloride dihydrate: 0.00081 g/L
#   Nicotinic acid: 0.00106 g/L
#   Calcium pantothenate: 0.00106 g/L
#   Pyridoxine-HCl: 0.00106 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00012 g/L
#   Zinc sulphate heptahydrate: 0.00612 g/L
#   Calcium chloride dihydrate: 0.04662 g/L
#   Inositol: 0.00003 g/L
#   para-aminobenzoic acid: 0.00009 g/L
#   Boric acid: 0.00079 g/L
# Sample 190:
#   Potassium iodide: 0.00003 g/L
#   Copper (II) sulphate: 0.00003 g/L
#   Iron sulphate heptahydrate: 0.00875 g/L
#   Sodium molybdate dihydrate: 0.00117 g/L
#   Cobalt (II) chloride hexahydrate: 0.00087 g/L
#   Magnesium sulphate heptahydrate: 0.34542 g/L
#   Manganese (II) chloride dihydrate: 0.00057 g/L
#   Nicotinic acid: 0.00053 g/L
#   Calcium pantothenate: 0.00053 g/L
#   Pyridoxine-HCl: 0.00053 g/L
#   Biotin: 0.00001 g/L
#   Thiamine hydrochloride: 0.00020 g/L
#   Zinc sulphate heptahydrate: 0.00237 g/L
#   Calcium chloride dihydrate: 0.01731 g/L
#   Inositol: 0.00000 g/L
#   para-aminobenzoic acid: 0.00010 g/L
#   Boric acid: 0.00062 g/L

# %%
def plot_sampled_vs_expanded(decoded_samples, df_min_max, title="Sampled Concentrations vs Expanded Ranges"):
    import matplotlib.pyplot as plt

    # Group all decoded concentrations into lists per compound
    from collections import defaultdict
    concentration_dict = defaultdict(list)
    for sample in decoded_samples:
        for compound, conc in sample.items():
            concentration_dict[compound].append(conc)

    # Merge into single DataFrame with all summary stats
    df = df_min_max.copy()
    df["Sampled_Min"] = df["Compound"].map(lambda c: np.min(concentration_dict[c]) if c in concentration_dict else np.nan)
    df["Sampled_Max"] = df["Compound"].map(lambda c: np.max(concentration_dict[c]) if c in concentration_dict else np.nan)
    df["Sampled_Median"] = df["Compound"].map(lambda c: np.median(concentration_dict[c]) if c in concentration_dict else np.nan)

    # Sort for cleaner plotting
    df_sorted = df.sort_values(by="Median")

    # Plotting
    plt.figure(figsize=(14, 6))
    for i, row in enumerate(df_sorted.itertuples()):
        y = i

        # Original Min–Max
        plt.plot([row.Min, row.Max], [y, y], color='black', lw=1.5, label='Min–Max' if i == 0 else "")
        
        # Expanded Range
        plt.plot([row.Expanded_Min, row.Expanded_Max], [y, y], color='skyblue', lw=6, alpha=0.4, label='Expanded Range' if i == 0 else "")
        
        # Sampled Range
        plt.plot([row.Sampled_Min, row.Sampled_Max], [y, y], color='red', lw=3, alpha=0.5, label='Sampled Range' if i == 0 else "")
        
        # Mean and Median markers
        plt.plot(row.Median, y, 'o', color='green', label='Median' if i == 0 else "")
        plt.plot(row.Mean, y, 'x', color='orange', label='Mean' if i == 0 else "")

    plt.yticks(range(len(df_sorted)), df_sorted['Compound'])
    plt.xlabel("Concentration (g/L)")
    plt.title(title)
    plt.legend(loc='lower right')
    plt.xscale('log')
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.tight_layout()
    plt.show()

def plot_sampled_vs_expanded_with_points(decoded_samples, df_min_max, title="Sampled Concentrations vs Expanded Ranges"):
    import matplotlib.pyplot as plt
    from collections import defaultdict

    # Group all decoded concentrations into lists per compound
    concentration_dict = defaultdict(list)
    for sample in decoded_samples:
        for compound, conc in sample.items():
            concentration_dict[compound].append(conc)

    # Merge into single DataFrame with all summary stats
    df = df_min_max.copy()
    df["Sampled_Min"] = df["Compound"].map(lambda c: np.min(concentration_dict[c]) if c in concentration_dict else np.nan)
    df["Sampled_Max"] = df["Compound"].map(lambda c: np.max(concentration_dict[c]) if c in concentration_dict else np.nan)
    df["Sampled_Median"] = df["Compound"].map(lambda c: np.median(concentration_dict[c]) if c in concentration_dict else np.nan)

    # Sort for cleaner plotting
    df_sorted = df.sort_values(by="Median")

    plt.figure(figsize=(14, 6))
    for i, row in enumerate(df_sorted.itertuples()):
        y = i

        # Original Min–Max
        plt.plot([row.Min, row.Max], [y, y], color='black', lw=1.5, label='Min–Max' if i == 0 else "")
        
        # Expanded Range
        plt.plot([row.Expanded_Min, row.Expanded_Max], [y, y], color='skyblue', lw=6, alpha=0.4, label='Expanded Range' if i == 0 else "")
        
        # Sampled Range
        plt.plot([row.Sampled_Min, row.Sampled_Max], [y, y], color='red', lw=3, alpha=0.5, label='Sampled Range' if i == 0 else "")
        
        # Mean and Median markers
        plt.plot(row.Median, y, 'o', color='green', label='Median' if i == 0 else "")
        plt.plot(row.Mean, y, 'x', color='orange', label='Mean' if i == 0 else "")

        # --- Overlay individual LHS points ---
        if row.Compound in concentration_dict:
            y_points = np.full_like(concentration_dict[row.Compound], y)
            plt.scatter(concentration_dict[row.Compound], y_points, color='purple', s=30, alpha=0.6, label='LHS Points' if i == 0 else "")

    plt.yticks(range(len(df_sorted)), df_sorted['Compound'])
    plt.xlabel("Concentration (g/L)")
    plt.title(title)
    plt.legend(loc='lower right')
    plt.xscale('log')
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.tight_layout()
    plt.show()

# %%
def plot_sampled_vs_expanded_lhs_on_top(decoded_samples, df_min_max, title="Sampled vs Expanded Ranges with LHS on Top"):
    import matplotlib.pyplot as plt
    import numpy as np
    from collections import defaultdict
    import matplotlib.cm as cm

    # Group all decoded concentrations per compound
    compound_to_samples = defaultdict(list)
    for sample in decoded_samples:
        for compound, conc in sample.items():
            compound_to_samples[compound].append(conc)

    # Merge into single DataFrame with summary stats
    df = df_min_max.copy()
    df["Sampled_Min"] = df["Compound"].map(lambda c: np.min(compound_to_samples[c]) if c in compound_to_samples else np.nan)
    df["Sampled_Max"] = df["Compound"].map(lambda c: np.max(compound_to_samples[c]) if c in compound_to_samples else np.nan)
    df["Sampled_Median"] = df["Compound"].map(lambda c: np.median(compound_to_samples[c]) if c in compound_to_samples else np.nan)

    df_sorted = df.sort_values(by="Median")

    n_samples = len(decoded_samples)
    colors = cm.get_cmap("tab20", n_samples)  # distinct color per LHS sample

    plt.figure(figsize=(14, 6))

    # --- Plot ranges and summary markers first ---
    for i, row in enumerate(df_sorted.itertuples()):
        y = i

        # Original Min–Max
        #plt.plot([row.Min, row.Max], [y, y], color='black', lw=1.5, label='Min–Max' if i == 0 else "")
        
        # Expanded Range
        #plt.plot([row.Expanded_Min, row.Expanded_Max], [y, y], color='skyblue', lw=6, alpha=0.4, label='Expanded Range' if i == 0 else "")
        
        # Sampled Range
        #plt.plot([row.Sampled_Min, row.Sampled_Max], [y, y], color='red', lw=3, alpha=0.5, label='Sampled Range' if i == 0 else "")
        
        # Mean and Median markers
        plt.plot(row.Median, y, 'o', color='green', label='Median' if i == 0 else "")
        plt.plot(row.Mean, y, 'x', color='orange', label='Mean' if i == 0 else "")

    # --- Plot LHS sample points on top ---
    for j, sample in enumerate(decoded_samples):
        for i, compound in enumerate(df_sorted['Compound']):
            conc = sample[compound]
            y_pos = i
            plt.scatter(conc, y_pos, color=colors(j), s=40, alpha=0.8, edgecolor='k', label='LHS Samples' if j == 0 and i == 0 else "")

    plt.yticks(range(len(df_sorted)), df_sorted['Compound'])
    plt.xlabel("Concentration (g/L)")
    plt.title(title)
    plt.legend(loc='lower right')
    plt.xscale('log')
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.tight_layout()
    plt.show()

# %%
# Decode all LHS or BO points
decoded_samples = [
    decode_bo_sample(sample, keys, scaler_map, pd.concat([df_v_min_max, df_e_min_max]))
    for sample in scaled_lhs_design
]

# Plot
plot_sampled_vs_expanded(
    decoded_samples,
    df_min_max=pd.concat([df_v_min_max, df_e_min_max]),
    title="Sampled vs Expanded Ranges for Each Compound"
)

# Plot
plot_sampled_vs_expanded_with_points(
    decoded_samples,
    df_min_max=pd.concat([df_v_min_max, df_e_min_max]),
    title="Sampled vs Expanded Ranges for Each Compound w/ LHS points"
)

plot_sampled_vs_expanded_lhs_on_top(
    decoded_samples,
    df_min_max=pd.concat([df_v_min_max, df_e_min_max]),
    title="Sampled vs Expanded Ranges for Each Compound with lhs points colored by sample"
)
# Out:
# C:\Users\uqkmuroi\AppData\Local\Temp\ipykernel_35040\764608439.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", n_samples)  # distinct color per LHS sample

# %%
def build_sample_matrix(decoded_samples, compound_order=None):
    """
    Builds a DataFrame of decoded samples (g/L) with samples as rows, compounds as columns.

    Args:
        decoded_samples (list of dict): Output from decode_bo_sample for each point.
        compound_order (list, optional): To enforce a specific column order.

    Returns:
        pd.DataFrame: Rows = samples, Columns = compound names
    """
    df = pd.DataFrame(decoded_samples)
    if compound_order:
        df = df[compound_order]  # reorder columns
    return df

# %%
# Decode samples if not done yet
decoded_samples = [
    decode_bo_sample(sample, keys, scaler_map, pd.concat([df_v_min_max, df_e_min_max]))
    for sample in scaled_lhs_design
]

# Create sample matrix
compound_order = sorted(decoded_samples[0].keys())  # or use custom order
sample_matrix_df = build_sample_matrix(decoded_samples, compound_order)

# Optional: Add comment row for units (will be skipped by pandas when loading)
units_row = pd.DataFrame([["g/L"] * sample_matrix_df.shape[1]], columns=sample_matrix_df.columns)
final_df = pd.concat([units_row, sample_matrix_df], ignore_index=True)

# Export
final_df.to_csv("./Generator 2 io data/bo_samples_compound_matrix_191.csv", index=False)

# %%
# this creates the file in the transposed for that makes it easy to conver to the file that JULIA expects, with compounds as rows and samples as columns

# manual processing is required here as you have to ensure you know the ratio values and pick the representative compound for each cluster.

def export_samples_transposed(decoded_samples, filename="bo_samples_transposed.csv"):
    """
    Save decoded samples with compounds as rows and samples as columns.
    """
    # Turn into DataFrame
    df = pd.DataFrame(decoded_samples)

    # Transpose so compounds are rows, samples are columns
    df_t = df.T
    df_t.columns = [f"Sample_{i+1}" for i in range(df_t.shape[1])]
    df_t.insert(0, "Compound", df_t.index)

    # Optional: add units row
    units_row = pd.DataFrame([["g/L"] + [""] * (df_t.shape[1] - 1)], columns=df_t.columns)

    # Combine and export
    df_final = pd.concat([units_row, df_t], ignore_index=True)
    df_final.to_csv(filename, index=False)

# %%
export_samples_transposed(
    decoded_samples,
    filename="./Generator 2 io data/bo_samples_compoundwise_191.csv"
)

# %%
def get_max_concentrations_from_bo_bounds(bo_bounds, scaler_map):
    """
    Computes the maximum concentration (g/L) each compound can reach based on bo_bounds.

    Args:
        bo_bounds (dict): keys are either cluster names or individual compounds, values are (min, max) tuples in log10/alpha space
        scaler_map (dict): maps cluster names to their ClusterScaler instances

    Returns:
        pd.DataFrame with compound-level max concentration values
    """
    rows = []

    for key, (min_val, max_val) in bo_bounds.items():
        if key in scaler_map:
            # Cluster key → decode using alpha
            decoded = scaler_map[key].concentration_from_alpha(max_val)
            for compound, conc in decoded.items():
                rows.append({
                    "Compound": compound,
                    "Max_Concentration (g/L)": conc,
                    "Source": f"{key} (alpha_max)"
                })
        else:
            # Individual compound → log10-transformed
            conc = 10 ** max_val
            rows.append({
                "Compound": key,
                "Max_Concentration (g/L)": conc,
                "Source": "individual (log10 max)"
            })

    df_max = pd.DataFrame(rows).sort_values("Compound").reset_index(drop=True)
    return df_max

# %%
df_max_conc = get_max_concentrations_from_bo_bounds(bo_bounds, scaler_map)
df_max_conc.to_csv("./Generator 2 io data/bo_max_concentrations_per_compound.csv", index=False)

# %%
print(df_v_min_max)
print(df_e_min_max)
# Out:
#                   Compound       Min       Max    Median      Mean  \
# 23          Pyridoxine-HCl  0.000500  0.001500  0.001000  0.001000
# 13                Inositol  0.000002  0.037500  0.012500  0.015001
# 33  para-aminobenzoic acid  0.000030  0.000200  0.000100  0.000110
# 28  Thiamine hydrochloride  0.000112  0.001500  0.000500  0.000667
# 2               Boric acid  0.000500  0.002000  0.001000  0.001167
# 4     Calcium pantothenate  0.000500  0.001500  0.001000  0.001000
# 21          Nicotinic acid  0.000500  0.001500  0.001000  0.001000
# 1                   Biotin  0.000008  0.000075  0.000025  0.000033
#
#     Expanded_Min  Expanded_Max
# 23      0.000455      0.001650
# 13      0.000002      0.041250
# 33      0.000027      0.000220
# 28      0.000102      0.001650
# 2       0.000455      0.002200
# 4       0.000455      0.001650
# 21      0.000455      0.001650
# 1       0.000007      0.000083
#                              Compound       Min       Max    Median      Mean  \
# 7                Copper (II) sulphate  0.000026  0.000192  0.000128  0.000115
# 32         Zinc sulphate heptahydrate  0.000400  0.014375  0.006750  0.007069
# 17  Manganese (II) chloride dihydrate  0.000400  0.001640  0.000820  0.000920
# 3          Calcium chloride dihydrate  0.003020  0.132465  0.008125  0.037934
# 6    Cobalt (II) chloride hexahydrate  0.000300  0.001175  0.000600  0.000692
# 16    Magnesium sulphate heptahydrate  0.500000  0.800000  0.500000  0.575000
# 22                   Potassium iodide  0.000100  0.000200  0.000100  0.000133
# 26         Sodium molybdate dihydrate  0.000400  0.001200  0.000800  0.000800
# 15         Iron sulphate heptahydrate  0.003000  0.007000  0.006000  0.005333
#
#     Expanded_Min  Expanded_Max
# 7       0.000023      0.000211
# 32      0.000364      0.015812
# 17      0.000364      0.001804
# 3       0.002745      0.145712
# 6       0.000273      0.001293
# 16      0.454545      0.880000
# 22      0.000091      0.000220
# 26      0.000364      0.001320
# 15      0.002727      0.007700
